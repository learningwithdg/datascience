# %% [markdown]
# # Pandas
# ---
#
# macosx
#
# export LC_ALL=en_US.UTF-8
#
# export LANG=en_US.UTF-8

# %%
import pandas as pd

# %% [markdown]
# ### Reading from csv file

# %%
# %ls ../data
# Out:
# countries.csv  nepal/  README

# %% [markdown]
# *let's use countries.csv file*

# %%
df = pd.read_csv('../data/countries.csv')

# %%
df
# Out:
#                                      Name Code
# 0                             Afghanistan   AF
# 1                           Åland Islands   AX
# 2                                 Albania   AL
# 3                                 Algeria   DZ
# 4                          American Samoa   AS
# 5                                 Andorra   AD
# 6                                  Angola   AO
# 7                                Anguilla   AI
# 8                              Antarctica   AQ
# 9                     Antigua and Barbuda   AG
# 10                              Argentina   AR
# 11                                Armenia   AM
# 12                                  Aruba   AW
# 13                              Australia   AU
# 14                                Austria   AT
# 15                             Azerbaijan   AZ
# 16                                Bahamas   BS
# 17                                Bahrain   BH
# 18                             Bangladesh   BD
# 19                               Barbados   BB
# 20                                Belarus   BY
# 21                                Belgium   BE
# 22                                 Belize   BZ
# 23                                  Benin   BJ
# 24                                Bermuda   BM
# 25                                 Bhutan   BT
# 26        Bolivia, Plurinational State of   BO
# 27       Bonaire, Sint Eustatius and Saba   BQ
# 28                 Bosnia and Herzegovina   BA
# 29                               Botswana   BW
# ..                                    ...  ...
# 219          Tanzania, United Republic of   TZ
# 220                              Thailand   TH
# 221                           Timor-Leste   TL
# 222                                  Togo   TG
# 223                               Tokelau   TK
# 224                                 Tonga   TO
# 225                   Trinidad and Tobago   TT
# 226                               Tunisia   TN
# 227                                Turkey   TR
# 228                          Turkmenistan   TM
# 229              Turks and Caicos Islands   TC
# 230                                Tuvalu   TV
# 231                                Uganda   UG
# 232                               Ukraine   UA
# 233                  United Arab Emirates   AE
# 234                        United Kingdom   GB
# 235                         United States   US
# 236  United States Minor Outlying Islands   UM
# 237                               Uruguay   UY
# 238                            Uzbekistan   UZ
# 239                               Vanuatu   VU
# 240     Venezuela, Bolivarian Republic of   VE
# 241                              Viet Nam   VN
# 242               Virgin Islands, British   VG
# 243                  Virgin Islands, U.S.   VI
# 244                     Wallis and Futuna   WF
# 245                        Western Sahara   EH
# 246                                 Yemen   YE
# 247                                Zambia   ZM
# 248                              Zimbabwe   ZW
#
# [249 rows x 2 columns]

# %% [markdown]
# *If it gives encoding error, define encoding format*
#
# ```python
# df = pd.read_csv('../data/countries.csv', encoding='utf-8')
# ```

# %%
df.head()
# Out:
#              Name Code
# 0     Afghanistan   AF
# 1   Åland Islands   AX
# 2         Albania   AL
# 3         Algeria   DZ
# 4  American Samoa   AS

# %%
# select rows from 10 - 30
ndf = df[10: 30]

# %%
ndf.head()
# Out:
#          Name Code
# 10  Argentina   AR
# 11    Armenia   AM
# 12      Aruba   AW
# 13  Australia   AU
# 14    Austria   AT

# %%
# reset the index of our new dataframe "ndf" to start it from 0
ndf.reset_index()
# Out:
#     index                              Name Code
# 0      10                         Argentina   AR
# 1      11                           Armenia   AM
# 2      12                             Aruba   AW
# 3      13                         Australia   AU
# 4      14                           Austria   AT
# 5      15                        Azerbaijan   AZ
# 6      16                           Bahamas   BS
# 7      17                           Bahrain   BH
# 8      18                        Bangladesh   BD
# 9      19                          Barbados   BB
# 10     20                           Belarus   BY
# 11     21                           Belgium   BE
# 12     22                            Belize   BZ
# 13     23                             Benin   BJ
# 14     24                           Bermuda   BM
# 15     25                            Bhutan   BT
# 16     26   Bolivia, Plurinational State of   BO
# 17     27  Bonaire, Sint Eustatius and Saba   BQ
# 18     28            Bosnia and Herzegovina   BA
# 19     29                          Botswana   BW

# %% [markdown]
# *Every dataframe operation returns a new dataframe, ie it doesnot change the old one*

# %%
ndf.head()
# Out:
#          Name Code
# 10  Argentina   AR
# 11    Armenia   AM
# 12      Aruba   AW
# 13  Australia   AU
# 14    Austria   AT

# %%
# now drop the old index while resetting it instead of creating a new column
ndf.reset_index(drop=True)
# Out:
#                                 Name Code
# 0                          Argentina   AR
# 1                            Armenia   AM
# 2                              Aruba   AW
# 3                          Australia   AU
# 4                            Austria   AT
# 5                         Azerbaijan   AZ
# 6                            Bahamas   BS
# 7                            Bahrain   BH
# 8                         Bangladesh   BD
# 9                           Barbados   BB
# 10                           Belarus   BY
# 11                           Belgium   BE
# 12                            Belize   BZ
# 13                             Benin   BJ
# 14                           Bermuda   BM
# 15                            Bhutan   BT
# 16   Bolivia, Plurinational State of   BO
# 17  Bonaire, Sint Eustatius and Saba   BQ
# 18            Bosnia and Herzegovina   BA
# 19                          Botswana   BW

# %%
# set a new index out of a column
ndf.set_index("Code")
# Out:
#                                   Name
# Code
# AR                           Argentina
# AM                             Armenia
# AW                               Aruba
# AU                           Australia
# AT                             Austria
# AZ                          Azerbaijan
# BS                             Bahamas
# BH                             Bahrain
# BD                          Bangladesh
# BB                            Barbados
# BY                             Belarus
# BE                             Belgium
# BZ                              Belize
# BJ                               Benin
# BM                             Bermuda
# BT                              Bhutan
# BO     Bolivia, Plurinational State of
# BQ    Bonaire, Sint Eustatius and Saba
# BA              Bosnia and Herzegovina
# BW                            Botswana

# %%
ndf.head()
# Out:
#          Name Code
# 10  Argentina   AR
# 11    Armenia   AM
# 12      Aruba   AW
# 13  Australia   AU
# 14    Austria   AT

# %%
# index of dataframe
ndf.index
# Out:
# RangeIndex(start=10, stop=30, step=1)

# %%
mdf = ndf.set_index("Code")

# %%
mdf.head()
# Out:
#            Name
# Code
# AR    Argentina
# AM      Armenia
# AW        Aruba
# AU    Australia
# AT      Austria

# %%
mdf.index
# Out:
# Index(['AR', 'AM', 'AW', 'AU', 'AT', 'AZ', 'BS', 'BH', 'BD', 'BB', 'BY', 'BE',
#        'BZ', 'BJ', 'BM', 'BT', 'BO', 'BQ', 'BA', 'BW'],
#       dtype='object', name='Code')

# %%
mdf.columns
# Out:
# Index(['Name'], dtype='object')

# %%
df.columns
# Out:
# Index(['Name', 'Code'], dtype='object')

# %%
mdf
# Out:
#                                   Name
# Code
# AR                           Argentina
# AM                             Armenia
# AW                               Aruba
# AU                           Australia
# AT                             Austria
# AZ                          Azerbaijan
# BS                             Bahamas
# BH                             Bahrain
# BD                          Bangladesh
# BB                            Barbados
# BY                             Belarus
# BE                             Belgium
# BZ                              Belize
# BJ                               Benin
# BM                             Bermuda
# BT                              Bhutan
# BO     Bolivia, Plurinational State of
# BQ    Bonaire, Sint Eustatius and Saba
# BA              Bosnia and Herzegovina
# BW                            Botswana

# %%
mdf[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 3
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-5a27787a756c> in <module>()
# ----> 1 mdf[3]
#
# /usr/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /usr/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 3

# %%
mdf["Name"]
# Out:
# Code
# AR                           Argentina
# AM                             Armenia
# AW                               Aruba
# AU                           Australia
# AT                             Austria
# AZ                          Azerbaijan
# BS                             Bahamas
# BH                             Bahrain
# BD                          Bangladesh
# BB                            Barbados
# BY                             Belarus
# BE                             Belgium
# BZ                              Belize
# BJ                               Benin
# BM                             Bermuda
# BT                              Bhutan
# BO     Bolivia, Plurinational State of
# BQ    Bonaire, Sint Eustatius and Saba
# BA              Bosnia and Herzegovina
# BW                            Botswana
# Name: Name, dtype: object

# %%
mdf["AR"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'AR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-d1ac309b7716> in <module>()
# ----> 1 mdf["AR"]
#
# /usr/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /usr/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'AR'

# %%
mdf[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-9ed28a6d6ba0> in <module>()
# ----> 1 mdf[0]
#
# /usr/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /usr/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 0

# %%
mdf[2:5]
# Out:
#            Name
# Code
# AW        Aruba
# AU    Australia
# AT      Austria

# %%
mdf.ix["AW"]
# Out:
# Name    Aruba
# Name: AW, dtype: object

# %%
mdf.loc["AU"]
# Out:
# Name    Australia
# Name: AU, dtype: object

# %%
mdf.ix[0]
# Out:
# Name    Argentina
# Name: AR, dtype: object

# %%
mdf.loc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-ea50d249be70> in <module>()
# ----> 1 mdf.loc[0]
#
# /usr/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# /usr/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1464
#    1465         # fall thru to straight lookup
# -> 1466         self._has_valid_type(key, axis)
#    1467         return self._get_label(key, axis=axis)
#    1468
#
# /usr/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1391
#    1392             try:
# -> 1393                 key = self._convert_scalar_indexer(key, axis)
#    1394                 if key not in ax:
#    1395                     error()
#
# /usr/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
#     185         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     186         # a scalar
# --> 187         return ax._convert_scalar_indexer(key, kind=self.name)
#     188
#     189     def _convert_slice_indexer(self, key, axis):
#
# /usr/lib/python3.5/site-packages/pandas/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    1010             elif kind in ['loc'] and is_integer(key):
#    1011                 if not self.holds_integer():
# -> 1012                     return self._invalid_indexer('label', key)
#    1013
#    1014         return key
#
# /usr/lib/python3.5/site-packages/pandas/indexes/base.py in _invalid_indexer(self, form, key)
#    1123                         "indexers [{key}] of {kind}".format(
#    1124                             form=form, klass=type(self), key=key,
# -> 1125                             kind=type(key)))
#    1126
#    1127     def get_duplicates(self):
#
# TypeError: cannot do label indexing on <class 'pandas.indexes.base.Index'> with these indexers [0] of <class 'int'>

# %%
mdf.iloc[0]
# Out:
# Name    Argentina
# Name: AR, dtype: object

# %%
ndf.head()
# Out:
#          Name Code
# 10  Argentina   AR
# 11    Armenia   AM
# 12      Aruba   AW
# 13  Australia   AU
# 14    Austria   AT

# %%
ndf.reindex(columns=["Pop", "Name", "Code"]).head()
# Out:
#     Pop       Name Code
# 10  NaN  Argentina   AR
# 11  NaN    Armenia   AM
# 12  NaN      Aruba   AW
# 13  NaN  Australia   AU
# 14  NaN    Austria   AT

# %%
ndf.reindex(index=[8, 11, 10, 14, 13, 12])
# Out:
#          Name Code
# 8         NaN  NaN
# 11    Armenia   AM
# 10  Argentina   AR
# 14    Austria   AT
# 13  Australia   AU
# 12      Aruba   AW

# %%
df2 = pd.read_csv('../data/nepal/API_NPL_DS2_en_csv_v2.csv', 
                  skiprows=3)

# %%
df2.head()
# Out:
#   Country Name Country Code  \
# 0        Nepal          NPL
# 1        Nepal          NPL
# 2        Nepal          NPL
# 3        Nepal          NPL
# 4        Nepal          NPL
#
#                                       Indicator Name     Indicator Code  1960  \
# 0                   Agricultural machinery, tractors     AG.AGR.TRAC.NO   NaN
# 1  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS   NaN
# 2  Fertilizer consumption (kilograms per hectare ...     AG.CON.FERT.ZS   NaN
# 3                         Agricultural land (sq. km)     AG.LND.AGRI.K2   NaN
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS   NaN
#
#            1961          1962          1963          1964          1965  \
# 0    180.000000    190.000000    200.000000    215.000000    225.000000
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3  35530.000000  35530.000000  35630.000000  35530.000000  35530.000000
# 4     24.846154     24.846154     24.916084     24.846154     24.846154
#
#       ...               2007          2008          2009          2010  \
# 0     ...                NaN           NaN           NaN           NaN
# 1     ...                NaN           NaN           NaN           NaN
# 2     ...           1.608929      1.364865     18.202727     25.086697
# 3     ...       41660.000000  41520.000000  41400.000000  41260.000000
# 4     ...          29.061737     28.964074     28.880363     28.782700
#
#            2011          2012          2013  2014  2015  Unnamed: 60
# 0           NaN           NaN           NaN   NaN   NaN          NaN
# 1           NaN           NaN           NaN   NaN   NaN          NaN
# 2     34.883710     44.069877     57.728477   NaN   NaN          NaN
# 3  41266.000000  41210.000000  41210.000000   NaN   NaN          NaN
# 4     28.786885     28.747820     28.747820   NaN   NaN          NaN
#
# [5 rows x 61 columns]

# %%
df2['Country Name'].unique()
# Out:
# array(['Nepal'], dtype=object)

# %%
df2['Country Name'].describe()
# Out:
# count      1410
# unique        1
# top       Nepal
# freq       1410
# Name: Country Name, dtype: object

# %%
ag_df = df2[df2["Indicator Code"] == 'AG.AGR.TRAC.NO']

# %%
ag_df
# Out:
#   Country Name Country Code                    Indicator Name  Indicator Code  \
# 0        Nepal          NPL  Agricultural machinery, tractors  AG.AGR.TRAC.NO
#
#    1960   1961   1962   1963   1964   1965     ...       2007  2008  2009  \
# 0   NaN  180.0  190.0  200.0  215.0  225.0     ...        NaN   NaN   NaN
#
#    2010  2011  2012  2013  2014  2015  Unnamed: 60
# 0   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [1 rows x 61 columns]

# %%
ag_df.loc[:, "1960": "2015"]
# Out:
#    1960   1961   1962   1963   1964   1965   1966   1967   1968   1969  ...   \
# 0   NaN  180.0  190.0  200.0  215.0  225.0  320.0  420.0  510.0  610.0  ...
#
#    2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 56 columns]

# %%
ag_df
# Out:
#   Country Name Country Code                    Indicator Name  Indicator Code  \
# 0        Nepal          NPL  Agricultural machinery, tractors  AG.AGR.TRAC.NO
#
#    1960   1961   1962   1963   1964   1965     ...       2007  2008  2009  \
# 0   NaN  180.0  190.0  200.0  215.0  225.0     ...        NaN   NaN   NaN
#
#    2010  2011  2012  2013  2014  2015  Unnamed: 60
# 0   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [1 rows x 61 columns]

# %%
ag_df.drop(["Country Name", "Country Code", 
            "Indicator Name", "Indicator Code", "Unnamed: 60"], axis=1)
# Out:
#    1960   1961   1962   1963   1964   1965   1966   1967   1968   1969  ...   \
# 0   NaN  180.0  190.0  200.0  215.0  225.0  320.0  420.0  510.0  610.0  ...
#
#    2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 56 columns]

# %%
ag_df
# Out:
#   Country Name Country Code                    Indicator Name  Indicator Code  \
# 0        Nepal          NPL  Agricultural machinery, tractors  AG.AGR.TRAC.NO
#
#    1960   1961   1962   1963   1964   1965     ...       2007  2008  2009  \
# 0   NaN  180.0  190.0  200.0  215.0  225.0     ...        NaN   NaN   NaN
#
#    2010  2011  2012  2013  2014  2015  Unnamed: 60
# 0   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [1 rows x 61 columns]

# %%
ag_df.drop(["Country Name", "Country Code", 
            "Indicator Name", "Indicator Code", "Unnamed: 60"], 
           axis=1, inplace=True)
# Out:
# /usr/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
ag_df
# Out:
#    1960   1961   1962   1963   1964   1965   1966   1967   1968   1969  ...   \
# 0   NaN  180.0  190.0  200.0  215.0  225.0  320.0  420.0  510.0  610.0  ...
#
#    2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 56 columns]

# %%
ag_df.dropna()
# Out:
# Empty DataFrame
# Columns: [1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# Index: []
#
# [0 rows x 56 columns]

# %%
ag_df = ag_df.transpose()

# %%
ag_df
# Out:
#             0
# 1960      NaN
# 1961    180.0
# 1962    190.0
# 1963    200.0
# 1964    215.0
# 1965    225.0
# 1966    320.0
# 1967    420.0
# 1968    510.0
# 1969    610.0
# 1970    794.0
# 1971    800.0
# 1972    900.0
# 1973   1070.0
# 1974   1240.0
# 1975   1925.0
# 1976   1580.0
# 1977   1740.0
# 1978   1910.0
# 1979   2080.0
# 1980   2514.0
# 1981   2420.0
# 1982   2591.0
# 1983   2690.0
# 1984   2770.0
# 1985   2783.0
# 1986   3200.0
# 1987   3600.0
# 1988   4018.0
# 1989   4500.0
# 1990   5000.0
# 1991   5542.0
# 1992   7800.0
# 1993  10100.0
# 1994  12400.0
# 1995  14700.0
# 1996  17000.0
# 1997  19350.0
# 1998  21700.0
# 1999  24000.0
# 2000  26300.0
# 2001      NaN
# 2002      NaN
# 2003      NaN
# 2004      NaN
# 2005      NaN
# 2006      NaN
# 2007      NaN
# 2008      NaN
# 2009      NaN
# 2010      NaN
# 2011      NaN
# 2012      NaN
# 2013      NaN
# 2014      NaN
# 2015      NaN

# %%
ag_df.columns = ["Values"]

# %%
ag_df
# Out:
#        Values
# 1960      NaN
# 1961    180.0
# 1962    190.0
# 1963    200.0
# 1964    215.0
# 1965    225.0
# 1966    320.0
# 1967    420.0
# 1968    510.0
# 1969    610.0
# 1970    794.0
# 1971    800.0
# 1972    900.0
# 1973   1070.0
# 1974   1240.0
# 1975   1925.0
# 1976   1580.0
# 1977   1740.0
# 1978   1910.0
# 1979   2080.0
# 1980   2514.0
# 1981   2420.0
# 1982   2591.0
# 1983   2690.0
# 1984   2770.0
# 1985   2783.0
# 1986   3200.0
# 1987   3600.0
# 1988   4018.0
# 1989   4500.0
# 1990   5000.0
# 1991   5542.0
# 1992   7800.0
# 1993  10100.0
# 1994  12400.0
# 1995  14700.0
# 1996  17000.0
# 1997  19350.0
# 1998  21700.0
# 1999  24000.0
# 2000  26300.0
# 2001      NaN
# 2002      NaN
# 2003      NaN
# 2004      NaN
# 2005      NaN
# 2006      NaN
# 2007      NaN
# 2008      NaN
# 2009      NaN
# 2010      NaN
# 2011      NaN
# 2012      NaN
# 2013      NaN
# 2014      NaN
# 2015      NaN

# %%
ag_df = ag_df.dropna()

# %%
ag_df
# Out:
#        Values
# 1961    180.0
# 1962    190.0
# 1963    200.0
# 1964    215.0
# 1965    225.0
# 1966    320.0
# 1967    420.0
# 1968    510.0
# 1969    610.0
# 1970    794.0
# 1971    800.0
# 1972    900.0
# 1973   1070.0
# 1974   1240.0
# 1975   1925.0
# 1976   1580.0
# 1977   1740.0
# 1978   1910.0
# 1979   2080.0
# 1980   2514.0
# 1981   2420.0
# 1982   2591.0
# 1983   2690.0
# 1984   2770.0
# 1985   2783.0
# 1986   3200.0
# 1987   3600.0
# 1988   4018.0
# 1989   4500.0
# 1990   5000.0
# 1991   5542.0
# 1992   7800.0
# 1993  10100.0
# 1994  12400.0
# 1995  14700.0
# 1996  17000.0
# 1997  19350.0
# 1998  21700.0
# 1999  24000.0
# 2000  26300.0

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
ag_df.plot()

# %%
df2.head()
# Out:
#   Country Name Country Code  \
# 0        Nepal          NPL
# 1        Nepal          NPL
# 2        Nepal          NPL
# 3        Nepal          NPL
# 4        Nepal          NPL
#
#                                       Indicator Name     Indicator Code  1960  \
# 0                   Agricultural machinery, tractors     AG.AGR.TRAC.NO   NaN
# 1  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS   NaN
# 2  Fertilizer consumption (kilograms per hectare ...     AG.CON.FERT.ZS   NaN
# 3                         Agricultural land (sq. km)     AG.LND.AGRI.K2   NaN
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS   NaN
#
#            1961          1962          1963          1964          1965  \
# 0    180.000000    190.000000    200.000000    215.000000    225.000000
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3  35530.000000  35530.000000  35630.000000  35530.000000  35530.000000
# 4     24.846154     24.846154     24.916084     24.846154     24.846154
#
#       ...               2007          2008          2009          2010  \
# 0     ...                NaN           NaN           NaN           NaN
# 1     ...                NaN           NaN           NaN           NaN
# 2     ...           1.608929      1.364865     18.202727     25.086697
# 3     ...       41660.000000  41520.000000  41400.000000  41260.000000
# 4     ...          29.061737     28.964074     28.880363     28.782700
#
#            2011          2012          2013  2014  2015  Unnamed: 60
# 0           NaN           NaN           NaN   NaN   NaN          NaN
# 1           NaN           NaN           NaN   NaN   NaN          NaN
# 2     34.883710     44.069877     57.728477   NaN   NaN          NaN
# 3  41266.000000  41210.000000  41210.000000   NaN   NaN          NaN
# 4     28.786885     28.747820     28.747820   NaN   NaN          NaN
#
# [5 rows x 61 columns]

# %%
df2[(df2['2009'] > 1000) & (df2['2010'] < 4000)]
# Out:
#      Country Name Country Code  \
# 28          Nepal          NPL
# 44          Nepal          NPL
# 46          Nepal          NPL
# 50          Nepal          NPL
# 210         Nepal          NPL
# 272         Nepal          NPL
# 385         Nepal          NPL
# 392         Nepal          NPL
# 541         Nepal          NPL
# 559         Nepal          NPL
# 564         Nepal          NPL
# 803         Nepal          NPL
# 804         Nepal          NPL
# 824         Nepal          NPL
# 825         Nepal          NPL
# 1024        Nepal          NPL
# 1037        Nepal          NPL
# 1155        Nepal          NPL
#
#                                          Indicator Name     Indicator Code  \
# 28                        Cereal yield (kg per hectare)     AG.YLD.CREL.KG
# 44           Current account balance (BoP, current US$)     BN.CAB.XOKA.CD
# 46             Net financial account (BoP, current US$)     BN.FIN.TOTL.CD
# 50          Net errors and omissions (BoP, current US$)     BN.KAC.EOMS.CD
# 210   Residual, debt stock-flow reconciliation (curr...     DT.DOD.RSDL.CD
# 272      Net financial flows, others (NFL, current US$)     DT.NFL.MOTH.CD
# 385     CO2 emissions from liquid fuel consumption (kt)  EN.ATM.CO2E.LF.KT
# 392   Other greenhouse gas emissions, HFC, PFC and S...  EN.ATM.GHGO.KT.CE
# 541                  Cost to export (US$ per container)     IC.EXP.COST.CD
# 559                  Cost to import (US$ per container)     IC.IMP.COST.CD
# 564          Time required to enforce a contract (days)        IC.LGL.DURS
# 803       GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
# 804   GDP per capita, PPP (constant 2011 internation...  NY.GDP.PCAP.PP.KD
# 824       GNI per capita, PPP (current international $)  NY.GNP.PCAP.PP.CD
# 825   GNI per capita, PPP (constant 2011 internation...  NY.GNP.PCAP.PP.KD
# 1024                    Children (0-14) living with HIV        SH.HIV.0014
# 1037                          Number of maternal deaths        SH.MMR.DTHS
# 1155      GDP per person employed (constant 2011 PPP $)  SL.GDP.PCAP.EM.KD
#
#         1960      1961      1962      1963      1964     1965     ...       \
# 28       NaN  1846.600  1842.300  1843.900  1883.200  1867.30     ...
# 44       NaN       NaN       NaN       NaN       NaN      NaN     ...
# 46       NaN       NaN       NaN       NaN       NaN      NaN     ...
# 50       NaN       NaN       NaN       NaN       NaN      NaN     ...
# 210      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 272      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 385   80.674    80.674    88.008    99.009   121.011   146.68     ...
# 392      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 541      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 559      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 564      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 803      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 804      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 824      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 825      NaN       NaN       NaN       NaN       NaN      NaN     ...
# 1024     NaN       NaN       NaN       NaN       NaN      NaN     ...
# 1037     NaN       NaN       NaN       NaN       NaN      NaN     ...
# 1155     NaN       NaN       NaN       NaN       NaN      NaN     ...
#
#               2007          2008          2009          2010          2011  \
# 28    2.213300e+03  2.356200e+03  2.369100e+03  2.289900e+03  2.483900e+03
# 44    5.659483e+06  7.333418e+08  2.141416e+07 -1.276157e+08  2.886047e+08
# 46    9.877220e+07  7.396851e+08  1.604477e+08 -1.176303e+08  7.568023e+08
# 50    1.772458e+07 -1.072455e+08  7.031527e+06 -1.751317e+08  2.786521e+08
# 210   1.517180e+08  4.451600e+07  1.133160e+08 -6.983000e+06  2.905500e+07
# 272  -3.022000e+06  2.579000e+06  4.649000e+06 -2.149000e+06  1.517300e+07
# 385   1.719823e+03  2.046186e+03  2.618238e+03  2.841925e+03  2.900597e+03
# 392   2.984860e+02  6.272680e+02  1.059120e+03  7.994980e+02  7.994980e+02
# 541   1.600000e+03  1.764000e+03  1.764000e+03  1.960000e+03  1.960000e+03
# 559   1.725000e+03  1.900000e+03  1.825000e+03  2.095000e+03  2.095000e+03
# 564   1.025000e+03  1.025000e+03  1.025000e+03  1.025000e+03  9.100000e+02
# 803   1.668740e+03  1.787406e+03  1.863683e+03  1.956466e+03  2.042141e+03
# 804   1.771163e+03  1.860614e+03  1.925394e+03  1.996860e+03  2.042141e+03
# 824   1.690000e+03  1.800000e+03  1.890000e+03  1.970000e+03  2.050000e+03
# 825   1.788553e+03  1.878001e+03  1.947522e+03  2.012143e+03  2.053418e+03
# 1024  1.400000e+03  1.500000e+03  1.600000e+03  1.700000e+03  1.800000e+03
# 1037  2.700000e+03  2.500000e+03  2.300000e+03  2.200000e+03  2.000000e+03
# 1155  3.539830e+03  3.714060e+03  3.809620e+03  3.911620e+03  3.958340e+03
#
#               2012          2013          2014          2015  Unnamed: 60
# 28    2.714200e+03  2.569700e+03  2.747900e+03           NaN          NaN
# 44    5.769330e+08  1.160160e+09  4.962249e+08  2.446630e+09          NaN
# 46    8.349585e+08  1.390192e+09  7.982540e+08  2.691242e+09          NaN
# 50    5.646063e+07  6.309762e+07  1.608020e+08  8.297646e+07          NaN
# 210   7.863000e+06  5.778100e+07 -7.577400e+07           NaN          NaN
# 272   8.400000e+04  4.799000e+06  2.728000e+06           NaN          NaN
# 385            NaN           NaN           NaN           NaN          NaN
# 392   7.994980e+03           NaN           NaN           NaN          NaN
# 541   1.975000e+03  2.295000e+03  2.545000e+03           NaN          NaN
# 559   2.095000e+03  2.400000e+03  2.650000e+03           NaN          NaN
# 564   9.100000e+02  9.100000e+02  9.100000e+02  9.100000e+02          NaN
# 803   2.153736e+03  2.251832e+03  2.382889e+03  2.458133e+03          NaN
# 804   2.114781e+03  2.175637e+03  2.265053e+03  2.313393e+03          NaN
# 824   2.170000e+03  2.270000e+03  2.410000e+03  2.500000e+03          NaN
# 825   2.131921e+03  2.189399e+03  2.288235e+03           NaN          NaN
# 1024  1.900000e+03  1.900000e+03  2.000000e+03           NaN          NaN
# 1037  1.800000e+03  1.700000e+03  1.600000e+03  1.500000e+03          NaN
# 1155  4.054420e+03  4.107870e+03  4.228710e+03  4.335590e+03          NaN
#
# [18 rows x 61 columns]

# %%
df3 = df2.drop(["Country Name", "Country Code", "Indicator Name"], 
               axis=1)

# %%
df3.head()
# Out:
#       Indicator Code  1960          1961          1962          1963  \
# 0     AG.AGR.TRAC.NO   NaN    180.000000    190.000000    200.000000
# 1  AG.CON.FERT.PT.ZS   NaN           NaN           NaN           NaN
# 2     AG.CON.FERT.ZS   NaN           NaN           NaN           NaN
# 3     AG.LND.AGRI.K2   NaN  35530.000000  35530.000000  35630.000000
# 4     AG.LND.AGRI.ZS   NaN     24.846154     24.846154     24.916084
#
#            1964          1965          1966          1967          1968  \
# 0    215.000000    225.000000    320.000000    420.000000    510.000000
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3  35530.000000  35530.000000  35530.000000  35670.000000  35670.000000
# 4     24.846154     24.846154     24.846154     24.944056     24.944056
#
#       ...               2007          2008          2009          2010  \
# 0     ...                NaN           NaN           NaN           NaN
# 1     ...                NaN           NaN           NaN           NaN
# 2     ...           1.608929      1.364865     18.202727     25.086697
# 3     ...       41660.000000  41520.000000  41400.000000  41260.000000
# 4     ...          29.061737     28.964074     28.880363     28.782700
#
#            2011          2012          2013  2014  2015  Unnamed: 60
# 0           NaN           NaN           NaN   NaN   NaN          NaN
# 1           NaN           NaN           NaN   NaN   NaN          NaN
# 2     34.883710     44.069877     57.728477   NaN   NaN          NaN
# 3  41266.000000  41210.000000  41210.000000   NaN   NaN          NaN
# 4     28.786885     28.747820     28.747820   NaN   NaN          NaN
#
# [5 rows x 58 columns]

# %%
df3 = df3.transpose()

# %%
df3.head()
# Out:
#                           0                  1               2     \
# Indicator Code  AG.AGR.TRAC.NO  AG.CON.FERT.PT.ZS  AG.CON.FERT.ZS
# 1960                       NaN                NaN             NaN
# 1961                       180                NaN             NaN
# 1962                       190                NaN             NaN
# 1963                       200                NaN             NaN
#
#                           3               4               5     \
# Indicator Code  AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.HA
# 1960                       NaN             NaN             NaN
# 1961                     35530         24.8462       1.806e+06
# 1962                     35530         24.8462       1.806e+06
# 1963                     35630         24.9161       1.816e+06
#
#                              6               7               8     \
# Indicator Code  AG.LND.ARBL.HA.PC  AG.LND.ARBL.ZS  AG.LND.CREL.HA
# 1960                          NaN             NaN             NaN
# 1961                     0.176796         12.6294       1.715e+06
# 1962                     0.174038         12.6294      1.7245e+06
# 1963                     0.172221         12.6993      1.7255e+06
#
#                           9        ...               1400          1401  \
# Indicator Code  AG.LND.CROP.ZS     ...       WP_time_01.1  WP_time_01.2
# 1960                       NaN     ...                NaN           NaN
# 1961                  0.174825     ...                NaN           NaN
# 1962                  0.174825     ...                NaN           NaN
# 1963                  0.174825     ...                NaN           NaN
#
#                         1402          1403          1404         1405  \
# Indicator Code  WP_time_01.3  WP_time_01.8  WP_time_01.9  WP15163_4.1
# 1960                     NaN           NaN           NaN          NaN
# 1961                     NaN           NaN           NaN          NaN
# 1962                     NaN           NaN           NaN          NaN
# 1963                     NaN           NaN           NaN          NaN
#
#                        1406         1407         1408         1409
# Indicator Code  WP15163_4.2  WP15163_4.3  WP15163_4.8  WP15163_4.9
# 1960                    NaN          NaN          NaN          NaN
# 1961                    NaN          NaN          NaN          NaN
# 1962                    NaN          NaN          NaN          NaN
# 1963                    NaN          NaN          NaN          NaN
#
# [5 rows x 1410 columns]

# %%
df3.iloc[0]
# Out:
# 0          AG.AGR.TRAC.NO
# 1       AG.CON.FERT.PT.ZS
# 2          AG.CON.FERT.ZS
# 3          AG.LND.AGRI.K2
# 4          AG.LND.AGRI.ZS
# 5          AG.LND.ARBL.HA
# 6       AG.LND.ARBL.HA.PC
# 7          AG.LND.ARBL.ZS
# 8          AG.LND.CREL.HA
# 9          AG.LND.CROP.ZS
# 10      AG.LND.EL5M.RU.K2
# 11      AG.LND.EL5M.RU.ZS
# 12      AG.LND.EL5M.UR.K2
# 13      AG.LND.EL5M.UR.ZS
# 14         AG.LND.EL5M.ZS
# 15         AG.LND.FRST.K2
# 16         AG.LND.FRST.ZS
# 17      AG.LND.IRIG.AG.ZS
# 18         AG.LND.PRCP.MM
# 19         AG.LND.TOTL.K2
# 20      AG.LND.TOTL.RU.K2
# 21      AG.LND.TOTL.UR.K2
# 22         AG.LND.TRAC.ZS
# 23         AG.PRD.CREL.MT
# 24         AG.PRD.CROP.XD
# 25         AG.PRD.FOOD.XD
# 26         AG.PRD.LVSK.XD
# 27         AG.SRF.TOTL.K2
# 28         AG.YLD.CREL.KG
# 29      BG.GSR.NFSV.GD.ZS
#               ...
# 1380    TX.VAL.MRCH.R2.ZS
# 1381    TX.VAL.MRCH.R3.ZS
# 1382    TX.VAL.MRCH.R4.ZS
# 1383    TX.VAL.MRCH.R5.ZS
# 1384    TX.VAL.MRCH.R6.ZS
# 1385    TX.VAL.MRCH.RS.ZS
# 1386    TX.VAL.MRCH.WL.CD
# 1387    TX.VAL.MRCH.WR.ZS
# 1388    TX.VAL.MRCH.XD.WD
# 1389    TX.VAL.OTHR.ZS.WT
# 1390    TX.VAL.SERV.CD.WT
# 1391       TX.VAL.TECH.CD
# 1392    TX.VAL.TECH.MF.ZS
# 1393    TX.VAL.TRAN.ZS.WT
# 1394    TX.VAL.TRVL.ZS.WT
# 1395          VC.BTL.DETH
# 1396       VC.IDP.TOTL.HE
# 1397       VC.IDP.TOTL.LE
# 1398       VC.IHR.PSRC.P5
# 1399       VC.PKP.TOTL.UN
# 1400         WP_time_01.1
# 1401         WP_time_01.2
# 1402         WP_time_01.3
# 1403         WP_time_01.8
# 1404         WP_time_01.9
# 1405          WP15163_4.1
# 1406          WP15163_4.2
# 1407          WP15163_4.3
# 1408          WP15163_4.8
# 1409          WP15163_4.9
# Name: Indicator Code, dtype: object

# %%
df3.columns = df3.iloc[0]

# %%
df3.head()
# Out:
# Indicator Code  AG.AGR.TRAC.NO  AG.CON.FERT.PT.ZS  AG.CON.FERT.ZS  \
# Indicator Code  AG.AGR.TRAC.NO  AG.CON.FERT.PT.ZS  AG.CON.FERT.ZS
# 1960                       NaN                NaN             NaN
# 1961                       180                NaN             NaN
# 1962                       190                NaN             NaN
# 1963                       200                NaN             NaN
#
# Indicator Code  AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.HA  \
# Indicator Code  AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.HA
# 1960                       NaN             NaN             NaN
# 1961                     35530         24.8462       1.806e+06
# 1962                     35530         24.8462       1.806e+06
# 1963                     35630         24.9161       1.816e+06
#
# Indicator Code  AG.LND.ARBL.HA.PC  AG.LND.ARBL.ZS  AG.LND.CREL.HA  \
# Indicator Code  AG.LND.ARBL.HA.PC  AG.LND.ARBL.ZS  AG.LND.CREL.HA
# 1960                          NaN             NaN             NaN
# 1961                     0.176796         12.6294       1.715e+06
# 1962                     0.174038         12.6294      1.7245e+06
# 1963                     0.172221         12.6993      1.7255e+06
#
# Indicator Code  AG.LND.CROP.ZS     ...       WP_time_01.1  WP_time_01.2  \
# Indicator Code  AG.LND.CROP.ZS     ...       WP_time_01.1  WP_time_01.2
# 1960                       NaN     ...                NaN           NaN
# 1961                  0.174825     ...                NaN           NaN
# 1962                  0.174825     ...                NaN           NaN
# 1963                  0.174825     ...                NaN           NaN
#
# Indicator Code  WP_time_01.3  WP_time_01.8  WP_time_01.9  WP15163_4.1  \
# Indicator Code  WP_time_01.3  WP_time_01.8  WP_time_01.9  WP15163_4.1
# 1960                     NaN           NaN           NaN          NaN
# 1961                     NaN           NaN           NaN          NaN
# 1962                     NaN           NaN           NaN          NaN
# 1963                     NaN           NaN           NaN          NaN
#
# Indicator Code  WP15163_4.2  WP15163_4.3  WP15163_4.8  WP15163_4.9
# Indicator Code  WP15163_4.2  WP15163_4.3  WP15163_4.8  WP15163_4.9
# 1960                    NaN          NaN          NaN          NaN
# 1961                    NaN          NaN          NaN          NaN
# 1962                    NaN          NaN          NaN          NaN
# 1963                    NaN          NaN          NaN          NaN
#
# [5 rows x 1410 columns]

# %%
df3 = df3.drop("Indicator Code")

# %%
df3.head()
# Out:
# Indicator Code AG.AGR.TRAC.NO AG.CON.FERT.PT.ZS AG.CON.FERT.ZS AG.LND.AGRI.K2  \
# 1960                      NaN               NaN            NaN            NaN
# 1961                      180               NaN            NaN          35530
# 1962                      190               NaN            NaN          35530
# 1963                      200               NaN            NaN          35630
# 1964                      215               NaN            NaN          35530
#
# Indicator Code AG.LND.AGRI.ZS AG.LND.ARBL.HA AG.LND.ARBL.HA.PC AG.LND.ARBL.ZS  \
# 1960                      NaN            NaN               NaN            NaN
# 1961                  24.8462      1.806e+06          0.176796        12.6294
# 1962                  24.8462      1.806e+06          0.174038        12.6294
# 1963                  24.9161      1.816e+06          0.172221        12.6993
# 1964                  24.8462      1.806e+06           0.16847        12.6294
#
# Indicator Code AG.LND.CREL.HA AG.LND.CROP.ZS     ...     WP_time_01.1  \
# 1960                      NaN            NaN     ...              NaN
# 1961                1.715e+06       0.174825     ...              NaN
# 1962               1.7245e+06       0.174825     ...              NaN
# 1963               1.7255e+06       0.174825     ...              NaN
# 1964                1.742e+06       0.174825     ...              NaN
#
# Indicator Code WP_time_01.2 WP_time_01.3 WP_time_01.8 WP_time_01.9  \
# 1960                    NaN          NaN          NaN          NaN
# 1961                    NaN          NaN          NaN          NaN
# 1962                    NaN          NaN          NaN          NaN
# 1963                    NaN          NaN          NaN          NaN
# 1964                    NaN          NaN          NaN          NaN
#
# Indicator Code WP15163_4.1 WP15163_4.2 WP15163_4.3 WP15163_4.8 WP15163_4.9
# 1960                   NaN         NaN         NaN         NaN         NaN
# 1961                   NaN         NaN         NaN         NaN         NaN
# 1962                   NaN         NaN         NaN         NaN         NaN
# 1963                   NaN         NaN         NaN         NaN         NaN
# 1964                   NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 1410 columns]

# %%
df3[["AG.LND.ARBL.HA.PC", "AG.LND.AGRI.ZS"]].dropna()
# Out:
# Indicator Code AG.LND.ARBL.HA.PC AG.LND.AGRI.ZS
# 1961                    0.176796        24.8462
# 1962                    0.174038        24.8462
# 1963                    0.172221        24.9161
# 1964                     0.16847        24.8462
# 1965                    0.165612        24.8462
# 1966                    0.162693        24.8462
# 1967                    0.160872        24.9441
# 1968                    0.157843        24.9441
# 1969                    0.154796        24.9441
# 1970                    0.162927        25.8881
# 1971                    0.159657        25.8881
# 1972                    0.164561        26.7273
# 1973                    0.169764        27.6434
# 1974                    0.167329        27.9301
# 1975                     0.16487         28.035
# 1976                    0.162396        28.1469
# 1977                    0.159913        28.2517
# 1978                    0.157426        28.3566
# 1979                    0.154936        28.4615
# 1980                     0.15245        28.5664
# 1981                    0.150158        28.6923
# 1982                    0.146935        28.7175
# 1983                    0.143776        28.7427
# 1984                     0.14071        28.7678
# 1985                     0.13775         28.786
# 1986                    0.134917        28.8951
# 1987                    0.132188        28.9133
# 1988                    0.129481        28.9385
# 1989                    0.126702        28.9566
# 1990                     0.12381        28.9818
# 1991                    0.120807             29
# 1992                    0.117745        29.0783
# 1993                    0.114736        29.1566
# 1994                    0.111887         29.235
# 1995                    0.109261        29.3133
# 1996                     0.10686        29.3916
# 1997                    0.104656        29.4699
# 1998                    0.102644        29.5483
# 1999                     0.10081        29.6266
# 2000                   0.0991569        29.6414
# 2001                    0.097635        29.7245
# 2002                   0.0952402        29.5849
# 2003                   0.0930882        29.4873
# 2004                   0.0912766        29.4245
# 2005                   0.0893878        29.3129
# 2006                   0.0876161        29.1943
# 2007                   0.0859436        29.0617
# 2008                   0.0843299        28.9641
# 2009                   0.0827296        28.8804
# 2010                   0.0811135        28.7827
# 2011                   0.0795718        28.7869
# 2012                   0.0770167        28.7478
# 2013                   0.0759476        28.7478

# %%
df3[["AG.LND.ARBL.HA.PC", "AG.LND.AGRI.ZS"]].dropna().mean()
# Out:
# Indicator Code
# AG.LND.ARBL.HA.PC     0.129160
# AG.LND.AGRI.ZS       28.083518
# dtype: float64

# %%
df3[["AG.LND.ARBL.HA.PC", "AG.LND.AGRI.ZS"]].sort_values("AG.LND.ARBL.HA.PC", 
                                                         ascending=False)
# Out:
# Indicator Code AG.LND.ARBL.HA.PC AG.LND.AGRI.ZS
# 1961                    0.176796        24.8462
# 1962                    0.174038        24.8462
# 1963                    0.172221        24.9161
# 1973                    0.169764        27.6434
# 1964                     0.16847        24.8462
# 1974                    0.167329        27.9301
# 1965                    0.165612        24.8462
# 1975                     0.16487         28.035
# 1972                    0.164561        26.7273
# 1970                    0.162927        25.8881
# 1966                    0.162693        24.8462
# 1976                    0.162396        28.1469
# 1967                    0.160872        24.9441
# 1977                    0.159913        28.2517
# 1971                    0.159657        25.8881
# 1968                    0.157843        24.9441
# 1978                    0.157426        28.3566
# 1979                    0.154936        28.4615
# 1969                    0.154796        24.9441
# 1980                     0.15245        28.5664
# 1981                    0.150158        28.6923
# 1982                    0.146935        28.7175
# 1983                    0.143776        28.7427
# 1984                     0.14071        28.7678
# 1985                     0.13775         28.786
# 1986                    0.134917        28.8951
# 1987                    0.132188        28.9133
# 1988                    0.129481        28.9385
# 1989                    0.126702        28.9566
# 1990                     0.12381        28.9818
# 1991                    0.120807             29
# 1992                    0.117745        29.0783
# 1993                    0.114736        29.1566
# 1994                    0.111887         29.235
# 1995                    0.109261        29.3133
# 1996                     0.10686        29.3916
# 1997                    0.104656        29.4699
# 1998                    0.102644        29.5483
# 1999                     0.10081        29.6266
# 2000                   0.0991569        29.6414
# 2001                    0.097635        29.7245
# 2002                   0.0952402        29.5849
# 2003                   0.0930882        29.4873
# 2004                   0.0912766        29.4245
# 2005                   0.0893878        29.3129
# 2006                   0.0876161        29.1943
# 2007                   0.0859436        29.0617
# 2008                   0.0843299        28.9641
# 2009                   0.0827296        28.8804
# 2010                   0.0811135        28.7827
# 2011                   0.0795718        28.7869
# 2012                   0.0770167        28.7478
# 2013                   0.0759476        28.7478
# 1960                         NaN            NaN
# 2014                         NaN            NaN
# 2015                         NaN            NaN
# Unnamed: 60                  NaN            NaN

# %%
mdf.sort_index(ascending=False)
# Out:
#                                   Name
# Code
# BZ                              Belize
# BY                             Belarus
# BW                            Botswana
# BT                              Bhutan
# BS                             Bahamas
# BQ    Bonaire, Sint Eustatius and Saba
# BO     Bolivia, Plurinational State of
# BM                             Bermuda
# BJ                               Benin
# BH                             Bahrain
# BE                             Belgium
# BD                          Bangladesh
# BB                            Barbados
# BA              Bosnia and Herzegovina
# AZ                          Azerbaijan
# AW                               Aruba
# AU                           Australia
# AT                             Austria
# AR                           Argentina
# AM                             Armenia

# %%
mdf.sort_values("Name", ascending=False)
# Out:
#                                   Name
# Code
# BW                            Botswana
# BA              Bosnia and Herzegovina
# BQ    Bonaire, Sint Eustatius and Saba
# BO     Bolivia, Plurinational State of
# BT                              Bhutan
# BM                             Bermuda
# BJ                               Benin
# BZ                              Belize
# BE                             Belgium
# BY                             Belarus
# BB                            Barbados
# BD                          Bangladesh
# BH                             Bahrain
# BS                             Bahamas
# AZ                          Azerbaijan
# AT                             Austria
# AU                           Australia
# AW                               Aruba
# AM                             Armenia
# AR                           Argentina

# %%
ag_df.plot(kind='bar', color='cyan')

# %%
mdf.head()
# Out:
#            Name
# Code
# AR    Argentina
# AM      Armenia
# AW        Aruba
# AU    Australia
# AT      Austria

# %%
def lowercase(x):
    return x.lower()

# %%
lambda x: x.uppercase()
# Out:
# <function __main__.<lambda>>

# %%
mdf.Name
# Out:
# Code
# AR                           Argentina
# AM                             Armenia
# AW                               Aruba
# AU                           Australia
# AT                             Austria
# AZ                          Azerbaijan
# BS                             Bahamas
# BH                             Bahrain
# BD                          Bangladesh
# BB                            Barbados
# BY                             Belarus
# BE                             Belgium
# BZ                              Belize
# BJ                               Benin
# BM                             Bermuda
# BT                              Bhutan
# BO     Bolivia, Plurinational State of
# BQ    Bonaire, Sint Eustatius and Saba
# BA              Bosnia and Herzegovina
# BW                            Botswana
# Name: Name, dtype: object

# %%
mdf["Name"]
# Out:
# Code
# AR                           Argentina
# AM                             Armenia
# AW                               Aruba
# AU                           Australia
# AT                             Austria
# AZ                          Azerbaijan
# BS                             Bahamas
# BH                             Bahrain
# BD                          Bangladesh
# BB                            Barbados
# BY                             Belarus
# BE                             Belgium
# BZ                              Belize
# BJ                               Benin
# BM                             Bermuda
# BT                              Bhutan
# BO     Bolivia, Plurinational State of
# BQ    Bonaire, Sint Eustatius and Saba
# BA              Bosnia and Herzegovina
# BW                            Botswana
# Name: Name, dtype: object

# %%
df5 = mdf.Name.apply(lowercase)

# %%
df5.head()
# Out:
# Code
# AR    argentina
# AM      armenia
# AW        aruba
# AU    australia
# AT      austria
# Name: Name, dtype: object

# %%
mdf['Name'] = mdf.Name.apply(lambda x: x.upper())

# %%
mdf
# Out:
#                                   Name
# Code
# AR                           ARGENTINA
# AM                             ARMENIA
# AW                               ARUBA
# AU                           AUSTRALIA
# AT                             AUSTRIA
# AZ                          AZERBAIJAN
# BS                             BAHAMAS
# BH                             BAHRAIN
# BD                          BANGLADESH
# BB                            BARBADOS
# BY                             BELARUS
# BE                             BELGIUM
# BZ                              BELIZE
# BJ                               BENIN
# BM                             BERMUDA
# BT                              BHUTAN
# BO     BOLIVIA, PLURINATIONAL STATE OF
# BQ    BONAIRE, SINT EUSTATIUS AND SABA
# BA              BOSNIA AND HERZEGOVINA
# BW                            BOTSWANA

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/tutorials.html
#
# http://nbviewer.jupyter.org/urls/bitbucket.org/hrojas/learn-pandas/raw/master/lessons/02%20-%20Lesson.ipynb
