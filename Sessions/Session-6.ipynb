# %% [markdown]
# # Session 6
# ---

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('../Data/Pokemon.csv')

# %%
dataframe
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
dataframe.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
dataframe.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
dataframe.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
dataframe[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dataframe["Name"]
# Out:
# 0                      Bulbasaur
# 1                        Ivysaur
# 2                       Venusaur
# 3          VenusaurMega Venusaur
# 4                     Charmander
# 5                     Charmeleon
# 6                      Charizard
# 7      CharizardMega Charizard X
# 8      CharizardMega Charizard Y
# 9                       Squirtle
# 10                     Wartortle
# 11                     Blastoise
# 12       BlastoiseMega Blastoise
# 13                      Caterpie
# 14                       Metapod
# 15                    Butterfree
# 16                        Weedle
# 17                        Kakuna
# 18                      Beedrill
# 19         BeedrillMega Beedrill
# 20                        Pidgey
# 21                     Pidgeotto
# 22                       Pidgeot
# 23           PidgeotMega Pidgeot
# 24                       Rattata
# 25                      Raticate
# 26                       Spearow
# 27                        Fearow
# ...

# %%
series = dataframe["Type 1"]

# %%
series
# Out:
# 0         Grass
# 1         Grass
# 2         Grass
# 3         Grass
# 4          Fire
# 5          Fire
# 6          Fire
# 7          Fire
# 8          Fire
# 9         Water
# 10        Water
# 11        Water
# 12        Water
# 13          Bug
# 14          Bug
# 15          Bug
# 16          Bug
# 17          Bug
# 18          Bug
# 19          Bug
# 20       Normal
# 21       Normal
# 22       Normal
# 23       Normal
# 24       Normal
# 25       Normal
# 26       Normal
# 27       Normal
# 28       Poison
# 29       Poison
#          ...
# 770       Fairy
# 771    Fighting
# 772    Electric
# 773        Rock
# 774      Dragon
# 775      Dragon
# 776      Dragon
# 777       Steel
# 778       Ghost
# 779       Ghost
# 780       Ghost
# 781       Ghost
# 782       Ghost
# 783       Ghost
# 784       Ghost
# 785       Ghost
# 786       Ghost
# 787       Ghost
# 788         Ice
# 789         Ice
# 790      Flying
# 791      Flying
# 792       Fairy
# 793        Dark
# ...

# %%
dir(series)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
series[0]
# Out:
# 'Grass'

# %%
series[0:66]
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
# 5         Fire
# 6         Fire
# 7         Fire
# 8         Fire
# 9        Water
# 10       Water
# 11       Water
# 12       Water
# 13         Bug
# 14         Bug
# 15         Bug
# 16         Bug
# 17         Bug
# 18         Bug
# 19         Bug
# 20      Normal
# 21      Normal
# 22      Normal
# 23      Normal
# 24      Normal
# 25      Normal
# 26      Normal
# 27      Normal
# 28      Poison
# 29      Poison
#         ...
# 36      Poison
# 37      Poison
# 38      Poison
# 39      Poison
# 40       Fairy
# 41       Fairy
# 42        Fire
# 43        Fire
# 44      Normal
# 45      Normal
# 46      Poison
# 47      Poison
# 48       Grass
# 49       Grass
# 50       Grass
# 51         Bug
# 52         Bug
# 53         Bug
# 54         Bug
# 55      Ground
# 56      Ground
# 57      Normal
# 58      Normal
# 59       Water
# 60       Water
# 61    Fighting
# 62    Fighting
# 63        Fire
# ...

# %%
dataframe[0: 17]
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
dataframe["Name": "HP"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f8753c7a7e51> in <module>()
# ----> 1 dataframe["Name": "HP"]
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1950
#    1951         # see if we can slice the rows
# -> 1952         indexer = convert_to_index_sliceable(self, key)
#    1953         if indexer is not None:
#    1954             return self._getitem_slice(indexer)
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    1894     idx = obj.index
#    1895     if isinstance(key, slice):
# -> 1896         return idx._convert_slice_indexer(key, kind='getitem')
#    1897
#    1898     elif isinstance(key, compat.string_types):
#
# ...

# %%
dataframe[:, "Name": "HP"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-2afc2e37b641> in <module>()
# ----> 1 dataframe[:, "Name": "HP"]
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...

# %%
dataframe[["Name", "Type 2"]]
# Out:
#                           Name  Type 2
# 0                    Bulbasaur  Poison
# 1                      Ivysaur  Poison
# 2                     Venusaur  Poison
# 3        VenusaurMega Venusaur  Poison
# 4                   Charmander     NaN
# 5                   Charmeleon     NaN
# 6                    Charizard  Flying
# 7    CharizardMega Charizard X  Dragon
# 8    CharizardMega Charizard Y  Flying
# 9                     Squirtle     NaN
# 10                   Wartortle     NaN
# 11                   Blastoise     NaN
# 12     BlastoiseMega Blastoise     NaN
# 13                    Caterpie     NaN
# 14                     Metapod     NaN
# 15                  Butterfree  Flying
# 16                      Weedle  Poison
# 17                      Kakuna  Poison
# 18                    Beedrill  Poison
# 19       BeedrillMega Beedrill  Poison
# 20                      Pidgey  Flying
# 21                   Pidgeotto  Flying
# 22                     Pidgeot  Flying
# ...

# %%
help(dataframe.loc)
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  Purely label-location based indexer for selection by label.
#  |
#  |  ``.loc[]`` is primarily label based, but may also be used with a
#  |  boolean array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#  |    interpreted as a *label* of the index, and **never** as an
#  |    integer position along the index).
#  |  - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#  |  - A slice object with labels, e.g. ``'a':'f'`` (note that contrary
#  |    to usual python slices, **both** the start and the stop are included!).
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series, DataFrame
#  |    or Panel) and that returns valid output for indexing (one of the above)
#  |
#  |  ``.loc`` will raise a ``KeyError`` when the items are not found.
#  |
# ...

# %%
help(dataframe.iloc)
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series, DataFrame
#  |    or Panel) and that returns valid output for indexing (one of the above)
#  |
#  |  ``.iloc`` will raise ``IndexError`` if a requested indexer is
#  |  out-of-bounds, except *slice* indexers which allow out-of-bounds
#  |  indexing (this conforms with python/numpy *slice* semantics).
#  |
#  |  See more at :ref:`Selection by Position <indexing.integer>`
#  |
# ...

# %%
dataframe[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dataframe.loc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
dataframe.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
dataframe.loc['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [Name] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-4f35c04e2ef1> in <module>()
# ----> 1 dataframe.loc['Name']
#
# ...

# %%
dataframe.iloc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
ndf = dataframe[9:16]

# %%
ndf
# Out:
#      #                     Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 9    7                 Squirtle  Water     NaN    314  44      48       65
# 10   8                Wartortle  Water     NaN    405  59      63       80
# 11   9                Blastoise  Water     NaN    530  79      83      100
# 12   9  BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 13  10                 Caterpie    Bug     NaN    195  45      30       35
# 14  11                  Metapod    Bug     NaN    205  50      20       55
# 15  12               Butterfree    Bug  Flying    395  60      45       50
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 9        50       64     43           1      False
# 10       65       80     58           1      False
# 11       85      105     78           1      False
# 12      135      115     78           1      False
# 13       20       20     45           1      False
# 14       25       25     30           1      False
# ...

# %%
ndf.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [0] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-45edce31b728> in <module>()
# ----> 1 ndf.loc[0]
#
# ...

# %%
ndf.iloc[0]
# Out:
# #                    7
# Name          Squirtle
# Type 1           Water
# Type 2             NaN
# Total              314
# HP                  44
# Attack              48
# Defense             65
# Sp. Atk             50
# Sp. Def             64
# Speed               43
# Generation           1
# Legendary        False
# Name: 9, dtype: object

# %%
ndf.loc[9]
# Out:
# #                    7
# Name          Squirtle
# Type 1           Water
# Type 2             NaN
# Total              314
# HP                  44
# Attack              48
# Defense             65
# Sp. Atk             50
# Sp. Def             64
# Speed               43
# Generation           1
# Legendary        False
# Name: 9, dtype: object

# %%
dataframe.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
dataframe.loc[5]
# Out:
# #                      5
# Name          Charmeleon
# Type 1              Fire
# Type 2               NaN
# Total                405
# HP                    58
# Attack                64
# Defense               58
# Sp. Atk               80
# Sp. Def               65
# Speed                 80
# Generation             1
# Legendary          False
# Name: 5, dtype: object

# %%
dataframe.loc[5, "HP"]
# Out:
# 58

# %%
dataframe.loc[3:9, "HP"]
# Out:
# 3    80
# 4    39
# 5    58
# 6    78
# 7    78
# 8    78
# 9    44
# Name: HP, dtype: int64

# %%
dataframe.loc[3:9, "Name": "Total"]
# Out:
#                         Name Type 1  Type 2  Total
# 3      VenusaurMega Venusaur  Grass  Poison    625
# 4                 Charmander   Fire     NaN    309
# 5                 Charmeleon   Fire     NaN    405
# 6                  Charizard   Fire  Flying    534
# 7  CharizardMega Charizard X   Fire  Dragon    634
# 8  CharizardMega Charizard Y   Fire  Flying    634
# 9                   Squirtle  Water     NaN    314

# %%
mdf = dataframe.loc[3:9, ["Name", "Total"]]

# %%
mdf
# Out:
#                         Name  Total
# 3      VenusaurMega Venusaur    625
# 4                 Charmander    309
# 5                 Charmeleon    405
# 6                  Charizard    534
# 7  CharizardMega Charizard X    634
# 8  CharizardMega Charizard Y    634
# 9                   Squirtle    314

# %%
mdf.sum()
# Out:
# Name     VenusaurMega VenusaurCharmanderCharmeleonChari...
# Total                                                 3455
# dtype: object

# %%
mdf.mean()
# Out:
# Total    493.571429
# dtype: float64

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 3 to 9
# Data columns (total 2 columns):
# Name     7 non-null object
# Total    7 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
mdf = dataframe.loc[:, "Name":"Total"]

# %%
mdf.head()
# Out:
#                     Name Type 1  Type 2  Total
# 0              Bulbasaur  Grass  Poison    318
# 1                Ivysaur  Grass  Poison    405
# 2               Venusaur  Grass  Poison    525
# 3  VenusaurMega Venusaur  Grass  Poison    625
# 4             Charmander   Fire     NaN    309

# %%
mdf["Type 1"] == 'Fire'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 770    False
# 771    False
# 772    False
# 773    False
# 774    False
# 775    False
# 776    False
# 777    False
# 778    False
# 779    False
# 780    False
# 781    False
# 782    False
# 783    False
# 784    False
# 785    False
# 786    False
# 787    False
# 788    False
# 789    False
# 790    False
# 791    False
# 792    False
# 793    False
# 794    False
# 795    False
# 796    False
# 797    False
# 798    False
# 799     True
# Name: Type 1, Length: 800, dtype: bool

# %%
mdf[mdf["Type 1"] == 'Fire']
# Out:
#                           Name Type 1    Type 2  Total
# 4                   Charmander   Fire       NaN    309
# 5                   Charmeleon   Fire       NaN    405
# 6                    Charizard   Fire    Flying    534
# 7    CharizardMega Charizard X   Fire    Dragon    634
# 8    CharizardMega Charizard Y   Fire    Flying    634
# 42                      Vulpix   Fire       NaN    299
# 43                   Ninetales   Fire       NaN    505
# 63                   Growlithe   Fire       NaN    350
# 64                    Arcanine   Fire       NaN    555
# 83                      Ponyta   Fire       NaN    410
# 84                    Rapidash   Fire       NaN    500
# 135                     Magmar   Fire       NaN    495
# 147                    Flareon   Fire       NaN    525
# 158                    Moltres   Fire    Flying    580
# 169                  Cyndaquil   Fire       NaN    309
# 170                    Quilava   Fire       NaN    405
# ...

# %%
mdf[mdf["Type 1"] == 'Fire'].count()
# Out:
# Name      52
# Type 1    52
# Type 2    24
# Total     52
# dtype: int64

# %%
mdf[(mdf["Type 1"] == 'Fire') & (mdf['Type 2'] == 'Flying')]
# Out:
#                           Name Type 1  Type 2  Total
# 6                    Charizard   Fire  Flying    534
# 8    CharizardMega Charizard Y   Fire  Flying    634
# 158                    Moltres   Fire  Flying    580
# 270                      Ho-oh   Fire  Flying    680
# 730                Fletchinder   Fire  Flying    382
# 731                 Talonflame   Fire  Flying    499

# %%
mdf.max()
# Out:
# Name      Zygarde50% Forme
# Type 1               Water
# Total                  780
# dtype: object

# %%
mdf['Total'].max()
# Out:
# 780

# %%
dataframe.max()
# Out:
# #                          721
# Name          Zygarde50% Forme
# Type 1                   Water
# Total                      780
# HP                         255
# Attack                     190
# Defense                    230
# Sp. Atk                    194
# Sp. Def                    230
# Speed                      180
# Generation                   6
# Legendary                 True
# dtype: object

# %%
mdf['Total'].idxmax()
# Out:
# 163

# %%
mdf.loc[[mdf['Total'].idxmax()]]
# Out:
#                     Name   Type 1    Type 2  Total
# 163  MewtwoMega Mewtwo X  Psychic  Fighting    780

# %%
type(mdf.loc[[mdf['Total'].idxmax()]])
# Out:
# pandas.core.frame.DataFrame

# %%
mdf.loc[mdf['Total'].idxmax()]
# Out:
# Name      MewtwoMega Mewtwo X
# Type 1                Psychic
# Type 2               Fighting
# Total                     780
# Name: 163, dtype: object

# %%
type(mdf.loc[mdf['Total'].idxmax()])
# Out:
# pandas.core.series.Series

# %%
mdf.head(10)
# Out:
#                         Name Type 1  Type 2  Total
# 0                  Bulbasaur  Grass  Poison    318
# 1                    Ivysaur  Grass  Poison    405
# 2                   Venusaur  Grass  Poison    525
# 3      VenusaurMega Venusaur  Grass  Poison    625
# 4                 Charmander   Fire     NaN    309
# 5                 Charmeleon   Fire     NaN    405
# 6                  Charizard   Fire  Flying    534
# 7  CharizardMega Charizard X   Fire  Dragon    634
# 8  CharizardMega Charizard Y   Fire  Flying    634
# 9                   Squirtle  Water     NaN    314

# %%
mdf.groupby(["Type 1"])

# %%
mdf[["Type 1", "Total"]].groupby(["Type 1"]).mean()
# Out:
#                Total
# Type 1
# Bug       378.927536
# Dark      445.741935
# Dragon    550.531250
# Electric  443.409091
# Fairy     413.176471
# Fighting  416.444444
# Fire      458.076923
# Flying    485.000000
# Ghost     439.562500
# Grass     421.142857
# Ground    437.500000
# Ice       433.458333
# Normal    401.683673
# Poison    399.142857
# Psychic   475.947368
# Rock      453.750000
# Steel     487.703704
# Water     430.455357

# %%
mdf.mean()
# Out:
# Total    435.1025
# dtype: float64

# %%
mdf[["Type 1", "Total"]]
# Out:
#        Type 1  Total
# 0       Grass    318
# 1       Grass    405
# 2       Grass    525
# 3       Grass    625
# 4        Fire    309
# 5        Fire    405
# 6        Fire    534
# 7        Fire    634
# 8        Fire    634
# 9       Water    314
# 10      Water    405
# 11      Water    530
# 12      Water    630
# 13        Bug    195
# 14        Bug    205
# 15        Bug    395
# 16        Bug    195
# 17        Bug    205
# 18        Bug    395
# 19        Bug    495
# 20     Normal    251
# 21     Normal    349
# 22     Normal    479
# 23     Normal    579
# 24     Normal    253
# 25     Normal    413
# 26     Normal    262
# 27     Normal    442
# 28     Poison    288
# 29     Poison    438
# ..        ...    ...
# 770     Fairy    525
# 771  Fighting    500
# 772  Electric    431
# 773      Rock    500
# 774    Dragon    300
# 775    Dragon    452
# 776    Dragon    600
# 777     Steel    470
# 778     Ghost    309
# 779     Ghost    474
# 780     Ghost    335
# ...

# %%
mdf[["Type 1", "Total"]].groupby(["Type 1"]).mean().plot(kind='bar')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
mdf[["Type 1", "Total"]].groupby(["Type 1"]).mean().plot(kind='bar')

# %%
import seaborn as sns

# %%
sns.set()

# %%
mdf[["Type 1", "Total"]].groupby(["Type 1"]).mean().plot(kind='bar')
