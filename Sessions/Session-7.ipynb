# %% [markdown]
# ### import libraries
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
# %matplotlib inline

# %% [markdown]
# ### load data
# ---

# %%
co2em = pd.read_excel('../Data/co2_emissions_v2.xls', sheetname='Data', skiprows=3)

# %%
co2em
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
help(pd.read_excel)
# Out:
# Help on function read_excel in module pandas.io.excel:
#
# read_excel(io, sheetname=0, header=0, skiprows=None, skip_footer=0, index_col=None, names=None, parse_cols=None, parse_dates=False, date_parser=None, na_values=None, thousands=None, convert_float=True, has_index_names=None, converters=None, dtype=None, true_values=None, false_values=None, engine=None, squeeze=False, **kwds)
#     Read an Excel table into a pandas DataFrame
#
#     Parameters
#     ----------
#     io : string, path object (pathlib.Path or py._path.local.LocalPath),
#         file-like object, pandas ExcelFile, or xlrd workbook.
#         The string could be a URL. Valid URL schemes include http, ftp, s3,
#         and file. For file URLs, a host is expected. For instance, a local
#         file could be file://localhost/path/to/workbook.xlsx
#     sheetname : string, int, mixed list of strings/ints, or None, default 0
#
#         Strings are used for sheet names, Integers are used in zero-indexed
# ...

# %%
co2em.head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 2       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 3      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
# 4      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
#
#        1961      1962      1963      1964      1965  ...        2007  \
# 0       NaN       NaN       NaN       NaN       NaN  ...    2592.569
# 1   491.378   689.396   707.731   839.743  1008.425  ...    2273.540
# 2   454.708  1180.774  1151.438  1224.778  1188.108  ...   25151.953
# 3  2280.874  2464.224  2082.856  2016.850  2174.531  ...    3927.357
# 4       NaN       NaN       NaN       NaN       NaN  ...     539.049
#
#         2008       2009       2010       2011       2012       2013  2014  \
# ...

# %%
co2em.shape
# Out:
# (264, 61)

# %%
co2em.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 61 columns):
# Country Name      264 non-null object
# Country Code      264 non-null object
# Indicator Name    264 non-null object
# Indicator Code    264 non-null object
# 1960              192 non-null float64
# 1961              193 non-null float64
# 1962              195 non-null float64
# 1963              196 non-null float64
# 1964              202 non-null float64
# 1965              202 non-null float64
# 1966              202 non-null float64
# 1967              202 non-null float64
# 1968              202 non-null float64
# 1969              202 non-null float64
# 1970              204 non-null float64
# 1971              205 non-null float64
# 1972              207 non-null float64
# 1973              207 non-null float64
# 1974              207 non-null float64
# 1975              207 non-null float64
# 1976              207 non-null float64
# ...

# %%
co2em = co2em.set_index('Country Name')

# %%
co2em.head()
# Out:
#              Country Code      Indicator Name  Indicator Code      1960  \
# Country Name
# Aruba                 ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# Afghanistan           AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# Angola                AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# Albania               ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
# Andorra               AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
#
#                   1961      1962      1963      1964      1965      1966  \
# Country Name
# Aruba              NaN       NaN       NaN       NaN       NaN       NaN
# Afghanistan    491.378   689.396   707.731   839.743  1008.425  1092.766
# Angola         454.708  1180.774  1151.438  1224.778  1188.108  1554.808
# Albania       2280.874  2464.224  2082.856  2016.850  2174.531  2552.232
# Andorra            NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
co2em.mean()
# Out:
# 1960    3.077045e+05
# 1961    2.960952e+05
# 1962    2.981522e+05
# 1963    3.110775e+05
# 1964    3.176523e+05
# 1965    3.351902e+05
# 1966    3.536254e+05
# 1967    3.619015e+05
# 1968    3.856930e+05
# 1969    4.156072e+05
# 1970    4.539379e+05
# 1971    4.725709e+05
# 1972    4.912489e+05
# 1973    5.200301e+05
# 1974    5.211013e+05
# 1975    5.268706e+05
# 1976    5.574860e+05
# 1977    5.795310e+05
# 1978    6.055252e+05
# 1979    6.288497e+05
# 1980    6.239282e+05
# 1981    6.100793e+05
# 1982    6.149125e+05
# 1983    6.235645e+05
# 1984    6.477647e+05
# 1985    6.717742e+05
# 1986    6.857462e+05
# 1987    7.131368e+05
# 1988    7.449930e+05
# 1989    7.637383e+05
# 1990    7.506518e+05
# 1991    7.793647e+05
# 1992    7.956876e+05
# 1993    8.000825e+05
# 1994    7.974480e+05
# 1995    8.094973e+05
# 1996    8.351023e+05
# 1997    8.294713e+05
# 1998    8.188389e+05
# 1999    8.294316e+05
# 2000    8.481020e+05
# 2001    8.596574e+05
# 2002    8.705010e+05
# ...

# %%
# did co2 emissions increased from 1960 to 2016
co2em.mean().plot()

# %%
co2em['1960']
# Out:
# Country Name
# Aruba                                                            NaN
# Afghanistan                                             4.143710e+02
# Angola                                                  5.500500e+02
# Albania                                                 2.024184e+03
# Andorra                                                          NaN
# Arab World                                              5.956408e+04
# United Arab Emirates                                    1.100100e+01
# Argentina                                               4.881510e+04
# Armenia                                                          NaN
# American Samoa                                                   NaN
# Antigua and Barbuda                                     3.667000e+01
# Australia                                               8.820235e+04
# Austria                                                 3.082113e+04
# ...

# %%
co2em.loc['Nepal']
# Out:
# Country Code                     NPL
# Indicator Name    CO2 emissions (kt)
# Indicator Code        EN.ATM.CO2E.KT
# 1960                          80.674
# 1961                          80.674
# 1962                          88.008
# 1963                          99.009
# 1964                         150.347
# 1965                         179.683
# 1966                         190.684
# 1967                         212.686
# 1968                         253.023
# 1969                         399.703
# 1970                         227.354
# 1971                         198.018
# 1972                         267.691
# 1973                         421.705
# 1974                         425.372
# 1975                         352.032
# 1976                         282.359
# 1977                         337.364
# 1978                          330.03
# 1979                          513.38
# 1980                         542.716
# 1981                         454.708
# ...

# %%
co2em.iloc[5]
# Out:
# Country Code                     ARB
# Indicator Name    CO2 emissions (kt)
# Indicator Code        EN.ATM.CO2E.KT
# 1960                         59564.1
# 1961                         65151.2
# 1962                         74357.8
# 1963                         87896.1
# 1964                          103196
# 1965                          123828
# 1966                          139079
# 1967                          149731
# 1968                          178805
# 1969                          213132
# 1970                          220576
# 1971                          250916
# 1972                          272873
# 1973                          318600
# 1974                          310922
# 1975                          307787
# 1976                          373497
# 1977                          395285
# 1978                          425912
# 1979                          456160
# 1980                          508781
# 1981                          497498
# ...

# %%
# which countries have maximium and minimum emissions in 1960 ?
co2em['1960'].idxmax()
# Out:
# 'World'

# %%
co2em.index
# Out:
# Index(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra', 'Arab World',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=264)

# %%
co2em.loc['World']
# Out:
# Country Code                     WLD
# Indicator Name    CO2 emissions (kt)
# Indicator Code        EN.ATM.CO2E.KT
# 1960                     9.38579e+06
# 1961                     9.41946e+06
# 1962                     9.80866e+06
# 1963                     1.03471e+07
# 1964                     1.09397e+07
# 1965                     1.14268e+07
# 1966                     1.19936e+07
# 1967                     1.23789e+07
# 1968                     1.30117e+07
# 1969                      1.3792e+07
# 1970                     1.47897e+07
# 1971                     1.53503e+07
# 1972                     1.59527e+07
# 1973                     1.68345e+07
# 1974                     1.69523e+07
# 1975                     1.68532e+07
# 1976                      1.7836e+07
# 1977                     1.83934e+07
# 1978                      1.8606e+07
# 1979                     1.96438e+07
# 1980                     1.94384e+07
# 1981                     1.88406e+07
# ...

# %%
del co2em.loc['World']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-55fd9b31dada> in <module>()
# ----> 1 del co2em.loc['World']
#
# AttributeError: __delitem__

# %%
help(co2em.drop)
# Out:
# Help on method drop in module pandas.core.generic:
#
# drop(labels, axis=0, level=None, inplace=False, errors='raise') method of pandas.core.frame.DataFrame instance
#     Return new object with labels in requested axis removed.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#     axis : int or axis name
#     level : int or level name, default None
#         For MultiIndex
#     inplace : bool, default False
#         If True, do operation inplace and return None.
#     errors : {'ignore', 'raise'}, default 'raise'
#         If 'ignore', suppress error and existing labels are dropped.
#
#         .. versionadded:: 0.16.1
#
#     Returns
#     -------
#     dropped : type of caller

# %%
co2em.drop(['World'])
# Out:
#                                                    Country Code  \
# Country Name
# Aruba                                                       ABW
# Afghanistan                                                 AFG
# Angola                                                      AGO
# Albania                                                     ALB
# Andorra                                                     AND
# Arab World                                                  ARB
# United Arab Emirates                                        ARE
# Argentina                                                   ARG
# Armenia                                                     ARM
# American Samoa                                              ASM
# Antigua and Barbuda                                         ATG
# Australia                                                   AUS
# Austria                                                     AUT
# ...

# %%
co2em.index
# Out:
# Index(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra', 'Arab World',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=264)

# %%
co2em.drop(['World'], inplace=True)

# %%
co2em.index
# Out:
# Index(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra', 'Arab World',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        ...
#        'British Virgin Islands', 'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu',
#        'Samoa', 'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=263)

# %%
# which countries have maximium and minimum emissions in 1960 ?
co2em['1960'].idxmax()
# Out:
# 'Post-demographic dividend'

# %%
list(co2em.index)
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'Arab World',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Channel Islands',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cuba',
#  'Curacao',
#  'Cayman Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
# ...

# %%
co2em.drop(['East Asia & Pacific (excluding high income)', 'Early-demographic dividend',
           'East Asia & Pacific', 'Europe & Central Asia (excluding high income)',
           'Europe & Central Asia', 'Fragile and conflict affected situations',
           'European Union', 'Euro area', 'Heavily indebted poor countries (HIPC)',
           'IBRD only', 'IDA & IBRD total', 'IDA total', 'IDA blend', 'IDA only', 'Not classified',
           'Latin America & Caribbean (excluding high income)', 'Latin America & Caribbean',
           'Least developed countries: UN classification', 'Low income', 'Lower middle income',
           'Low & middle income','Late-demographic dividend','Middle East & North Africa',
           'Middle East & North Africa (excluding high income)','OECD members', 'Other small states',
           'Pre-demographic dividend','Pacific island small states','Post-demographic dividend',
           'Sub-Saharan Africa (excluding high income)','Sub-Saharan Africa','Small states',
           'East Asia & Pacific (IDA & IBRD countries)','Europe & Central Asia (IDA & IBRD countries)',
           'Latin America & the Caribbean (IDA & IBRD countries)','Middle East & North Africa (IDA & IBRD countries)',
           'South Asia (IDA & IBRD)','Sub-Saharan Africa (IDA & IBRD countries)','Upper middle income',
           ], inplace=True)

# %%
# which countries have maximium and minimum emissions in 1960 ?
co2em['1960'].idxmax()
# Out:
# 'High income'

# %%
co2em.drop(['Caribbean small states','High income','North America'], inplace=True)

# %%
co2em.drop(['Middle income'], inplace=True)

# %%
# which countries have maximium and minimum emissions in 1960 ?
print(co2em['1960'].idxmax())
print(co2em['1960'].idxmin())
# Out:
# United States
# United Arab Emirates

# %%
# which countries have maximium and minimum emissions in 2013 ?
print(co2em['2013'].idxmax())
print(co2em['2013'].idxmin())
# Out:
# China
# Nauru

# %%
# increment percentage
co2em.drop(['Indicator Code', 'Indicator Name', 'Country Code'], axis=1, inplace=True)

# %%
co2em.head()
# Out:
#                   1960      1961      1962      1963      1964      1965  \
# Country Name
# Aruba              NaN       NaN       NaN       NaN       NaN       NaN
# Afghanistan    414.371   491.378   689.396   707.731   839.743  1008.425
# Angola         550.050   454.708  1180.774  1151.438  1224.778  1188.108
# Albania       2024.184  2280.874  2464.224  2082.856  2016.850  2174.531
# Andorra            NaN       NaN       NaN       NaN       NaN       NaN
#
#                   1966      1967      1968      1969  ...        2007  \
# Country Name                                          ...
# Aruba              NaN       NaN       NaN       NaN  ...    2592.569
# Afghanistan   1092.766  1283.450  1224.778   942.419  ...    2273.540
# Angola        1554.808   993.757  1672.152  2786.920  ...   25151.953
# Albania       2552.232  2680.577  3072.946  3245.295  ...    3927.357
# Andorra            NaN       NaN       NaN       NaN  ...     539.049
#
# ...

# %%
#co2em = co2em.loc[:, '1960': '2013']

# %%
#co2em.head()

# %%
co2em.loc['Nepal'].plot()

# %%
co2em.loc[['Nepal', 'Bhutan']].plot()

# %%
# co2em.loc['Nepal'].plot(legend='Nepal')
co2em.loc['Nepal'].plot()
co2em.loc['Bhutan'].plot()
plt.legend()

# %%
co2em.loc['Nepal'].plot()
co2em.loc['Bhutan'].plot()
co2em.loc['Sri Lanka'].plot()
plt.legend()

# %%
co2em.loc['Bhutan']
# Out:
# 1960        NaN
# 1961        NaN
# 1962        NaN
# 1963        NaN
# 1964        NaN
# 1965        NaN
# 1966        NaN
# 1967        NaN
# 1968        NaN
# 1969        NaN
# 1970      3.667
# 1971      3.667
# 1972      3.667
# 1973      3.667
# 1974      3.667
# 1975      3.667
# 1976      3.667
# 1977      7.334
# 1978     11.001
# 1979     22.002
# 1980     22.002
# 1981     25.669
# 1982     33.003
# 1983     29.336
# 1984     51.338
# 1985     62.339
# 1986     55.005
# 1987    102.676
# 1988    110.010
# 1989     62.339
# 1990    128.345
# 1991    187.017
# 1992    216.353
# 1993    183.350
# 1994    212.686
# 1995    249.356
# 1996    300.694
# 1997    392.369
# 1998    381.368
# 1999    385.035
# 2000    396.036
# 2001    385.035
# 2002    418.038
# 2003    377.701
# 2004    308.028
# 2005    396.036
# 2006    392.369
# 2007    392.369
# 2008    421.705
# 2009    388.702
# 2010    487.711
# 2011    733.400
# 2012    817.741
# 2013    883.747
# 2014        NaN
# ...

# %%
mdf = co2em.loc[['Nepal', 'Bhutan']]

# %%
mdf
# Out:
#                 1960    1961    1962    1963     1964     1965     1966  \
# Country Name
# Nepal         80.674  80.674  88.008  99.009  150.347  179.683  190.684
# Bhutan           NaN     NaN     NaN     NaN      NaN      NaN      NaN
#
#                  1967     1968     1969  ...       2007      2008      2009  \
# Country Name                             ...
# Nepal         212.686  253.023  399.703  ...   2614.571  3421.311  4334.394
# Bhutan            NaN      NaN      NaN  ...    392.369   421.705   388.702
#
#                   2010      2011      2012      2013  2014  2015  2016
# Country Name
# Nepal         5056.793  5533.503  5845.198  6501.591   NaN   NaN   NaN
# Bhutan         487.711   733.400   817.741   883.747   NaN   NaN   NaN
#
# [2 rows x 57 columns]

# %%
mdf.T
# Out:
# Country Name     Nepal   Bhutan
# 1960            80.674      NaN
# 1961            80.674      NaN
# 1962            88.008      NaN
# 1963            99.009      NaN
# 1964           150.347      NaN
# 1965           179.683      NaN
# 1966           190.684      NaN
# 1967           212.686      NaN
# 1968           253.023      NaN
# 1969           399.703      NaN
# 1970           227.354    3.667
# 1971           198.018    3.667
# 1972           267.691    3.667
# 1973           421.705    3.667
# 1974           425.372    3.667
# 1975           352.032    3.667
# 1976           282.359    3.667
# 1977           337.364    7.334
# 1978           330.030   11.001
# 1979           513.380   22.002
# 1980           542.716   22.002
# 1981           454.708   25.669
# 1982           443.707   33.003
# 1983           495.045   29.336
# 1984           704.064   51.338
# 1985           678.395   62.339
# 1986           704.064   55.005
# 1987           872.746  102.676
# ...

# %%
mdf = mdf.T

# %%
mdf
# Out:
# Country Name     Nepal   Bhutan
# 1960            80.674      NaN
# 1961            80.674      NaN
# 1962            88.008      NaN
# 1963            99.009      NaN
# 1964           150.347      NaN
# 1965           179.683      NaN
# 1966           190.684      NaN
# 1967           212.686      NaN
# 1968           253.023      NaN
# 1969           399.703      NaN
# 1970           227.354    3.667
# 1971           198.018    3.667
# 1972           267.691    3.667
# 1973           421.705    3.667
# 1974           425.372    3.667
# 1975           352.032    3.667
# 1976           282.359    3.667
# 1977           337.364    7.334
# 1978           330.030   11.001
# 1979           513.380   22.002
# 1980           542.716   22.002
# 1981           454.708   25.669
# 1982           443.707   33.003
# 1983           495.045   29.336
# 1984           704.064   51.338
# 1985           678.395   62.339
# 1986           704.064   55.005
# 1987           872.746  102.676
# ...

# %%
mdf.plot()

# %%
help(mdf.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False) method of pandas.core.frame.DataFrame instance
#     Return object with labels on given axis omitted where alternately any
#     or all of the data are missing
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, or tuple/list thereof
#         Pass tuple or list to drop on multiple axes
#     how : {'any', 'all'}
#         * any : if any NA values are present, drop that label
#         * all : if all values are NA, drop that label
#     thresh : int, default None
#         int value : require that many non-NA values
#     subset : array-like
#         Labels along other axis to consider, e.g. if you are dropping rows
#         these would be a list of columns to include
#     inplace : boolean, default False
#         If True, do operation inplace and return None.
#
#     Returns
#     -------
#     dropped : DataFrame
#
# ...

# %%
help(mdf.fillna)
# Out:
# Help on method fillna in module pandas.core.frame:
#
# fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs) method of pandas.core.frame.DataFrame instance
#     Fill NA/NaN values using the specified method
#
#     Parameters
#     ----------
#     value : scalar, dict, Series, or DataFrame
#         Value to use to fill holes (e.g. 0), alternately a
#         dict/Series/DataFrame of values specifying which value to use for
#         each index (for a Series) or column (for a DataFrame). (values not
#         in the dict/Series/DataFrame will not be filled). This value cannot
#         be a list.
#     method : {'backfill', 'bfill', 'pad', 'ffill', None}, default None
#         Method to use for filling holes in reindexed Series
#         pad / ffill: propagate last valid observation forward to next valid
#         backfill / bfill: use NEXT valid observation to fill gap
#     axis : {0 or 'index', 1 or 'columns'}
# ...

# %%
mdf.dropna(inplace=True)

# %%
mdf
# Out:
# Country Name     Nepal   Bhutan
# 1970           227.354    3.667
# 1971           198.018    3.667
# 1972           267.691    3.667
# 1973           421.705    3.667
# 1974           425.372    3.667
# 1975           352.032    3.667
# 1976           282.359    3.667
# 1977           337.364    7.334
# 1978           330.030   11.001
# 1979           513.380   22.002
# 1980           542.716   22.002
# 1981           454.708   25.669
# 1982           443.707   33.003
# 1983           495.045   29.336
# 1984           704.064   51.338
# 1985           678.395   62.339
# 1986           704.064   55.005
# 1987           872.746  102.676
# 1988           993.757  110.010
# 1989           913.083   62.339
# 1990           634.391  128.345
# 1991           960.754  187.017
# 1992          1331.121  216.353
# 1993          1466.800  183.350
# 1994          1697.821  212.686
# 1995          2035.185  249.356
# 1996          2486.226  300.694
# 1997          2783.253  392.369
# ...

# %%
mdf['diff'] = 0

# %%
mdf
# Out:
# Country Name     Nepal   Bhutan  diff
# 1970           227.354    3.667     0
# 1971           198.018    3.667     0
# 1972           267.691    3.667     0
# 1973           421.705    3.667     0
# 1974           425.372    3.667     0
# 1975           352.032    3.667     0
# 1976           282.359    3.667     0
# 1977           337.364    7.334     0
# 1978           330.030   11.001     0
# 1979           513.380   22.002     0
# 1980           542.716   22.002     0
# 1981           454.708   25.669     0
# 1982           443.707   33.003     0
# 1983           495.045   29.336     0
# 1984           704.064   51.338     0
# 1985           678.395   62.339     0
# 1986           704.064   55.005     0
# 1987           872.746  102.676     0
# 1988           993.757  110.010     0
# 1989           913.083   62.339     0
# 1990           634.391  128.345     0
# 1991           960.754  187.017     0
# 1992          1331.121  216.353     0
# 1993          1466.800  183.350     0
# ...

# %%
mdf['Nepal'] - mdf['Bhutan']
# Out:
# 1970     223.687
# 1971     194.351
# 1972     264.024
# 1973     418.038
# 1974     421.705
# 1975     348.365
# 1976     278.692
# 1977     330.030
# 1978     319.029
# 1979     491.378
# 1980     520.714
# 1981     429.039
# 1982     410.704
# 1983     465.709
# 1984     652.726
# 1985     616.056
# 1986     649.059
# 1987     770.070
# 1988     883.747
# 1989     850.744
# 1990     506.046
# 1991     773.737
# 1992    1114.768
# 1993    1283.450
# 1994    1485.135
# 1995    1785.829
# 1996    2185.532
# 1997    2390.884
# 1998    1870.170
# 1999    2834.591
# 2000    2673.243
# 2001    2882.262
# 2002    2207.534
# 2003    2464.224
# 2004    2361.548
# 2005    2687.911
# 2006    2170.864
# 2007    2222.202
# 2008    2999.606
# 2009    3945.692
# 2010    4569.082
# 2011    4800.103
# 2012    5027.457
# 2013    5617.844
# dtype: float64

# %%
mdf['diff'] = mdf['Nepal'] - mdf['Bhutan']

# %%
mdf
# Out:
# Country Name     Nepal   Bhutan      diff
# 1970           227.354    3.667   223.687
# 1971           198.018    3.667   194.351
# 1972           267.691    3.667   264.024
# 1973           421.705    3.667   418.038
# 1974           425.372    3.667   421.705
# 1975           352.032    3.667   348.365
# 1976           282.359    3.667   278.692
# 1977           337.364    7.334   330.030
# 1978           330.030   11.001   319.029
# 1979           513.380   22.002   491.378
# 1980           542.716   22.002   520.714
# 1981           454.708   25.669   429.039
# 1982           443.707   33.003   410.704
# 1983           495.045   29.336   465.709
# 1984           704.064   51.338   652.726
# 1985           678.395   62.339   616.056
# 1986           704.064   55.005   649.059
# 1987           872.746  102.676   770.070
# 1988           993.757  110.010   883.747
# 1989           913.083   62.339   850.744
# 1990           634.391  128.345   506.046
# ...

# %%
mdf['diff'].plot()

# %%
co2em.head()
# Out:
#                   1960      1961      1962      1963      1964      1965  \
# Country Name
# Aruba              NaN       NaN       NaN       NaN       NaN       NaN
# Afghanistan    414.371   491.378   689.396   707.731   839.743  1008.425
# Angola         550.050   454.708  1180.774  1151.438  1224.778  1188.108
# Albania       2024.184  2280.874  2464.224  2082.856  2016.850  2174.531
# Andorra            NaN       NaN       NaN       NaN       NaN       NaN
#
#                   1966      1967      1968      1969  ...        2007  \
# Country Name                                          ...
# Aruba              NaN       NaN       NaN       NaN  ...    2592.569
# Afghanistan   1092.766  1283.450  1224.778   942.419  ...    2273.540
# Angola        1554.808   993.757  1672.152  2786.920  ...   25151.953
# Albania       2552.232  2680.577  3072.946  3245.295  ...    3927.357
# Andorra            NaN       NaN       NaN       NaN  ...     539.049
#
# ...

# %%
co2em['percentage'] = 90

# %%
co2em.head()
# Out:
#                   1960      1961      1962      1963      1964      1965  \
# Country Name
# Aruba              NaN       NaN       NaN       NaN       NaN       NaN
# Afghanistan    414.371   491.378   689.396   707.731   839.743  1008.425
# Angola         550.050   454.708  1180.774  1151.438  1224.778  1188.108
# Albania       2024.184  2280.874  2464.224  2082.856  2016.850  2174.531
# Andorra            NaN       NaN       NaN       NaN       NaN       NaN
#
#                   1966      1967      1968      1969     ...           2008  \
# Country Name                                             ...
# Aruba              NaN       NaN       NaN       NaN     ...       2508.228
# Afghanistan   1092.766  1283.450  1224.778   942.419     ...       4217.050
# Angola        1554.808   993.757  1672.152  2786.920     ...      25709.337
# Albania       2552.232  2680.577  3072.946  3245.295     ...       4374.731
# ...

# %%
co2em['percentage'] = np.round((co2em['2013'] - co2em['1960']) / co2em['1960'], 2)

# %%
co2em.head()
# Out:
#                   1960      1961      1962      1963      1964      1965  \
# Country Name
# Aruba              NaN       NaN       NaN       NaN       NaN       NaN
# Afghanistan    414.371   491.378   689.396   707.731   839.743  1008.425
# Angola         550.050   454.708  1180.774  1151.438  1224.778  1188.108
# Albania       2024.184  2280.874  2464.224  2082.856  2016.850  2174.531
# Andorra            NaN       NaN       NaN       NaN       NaN       NaN
#
#                   1966      1967      1968      1969     ...           2008  \
# Country Name                                             ...
# Aruba              NaN       NaN       NaN       NaN     ...       2508.228
# Afghanistan   1092.766  1283.450  1224.778   942.419     ...       4217.050
# Angola        1554.808   993.757  1672.152  2786.920     ...      25709.337
# Albania       2552.232  2680.577  3072.946  3245.295     ...       4374.731
# ...

# %%
change = co2em['percentage']

# %%
change.head()
# Out:
# Country Name
# Aruba            NaN
# Afghanistan    50.33
# Angola         58.02
# Albania         1.38
# Andorra          NaN
# Name: percentage, dtype: float64

# %%
change = change.dropna().order(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-b5b8c7337d8f> in <module>()
# ----> 1 change = change.dropna().order(ascending=False)
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'order'

# %%
help(change.sort_values)
# Out:
# Help on method sort_values in module pandas.core.series:
#
# sort_values(axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last') method of pandas.core.series.Series instance
#     Sort by the values along either axis
#
#     .. versionadded:: 0.17.0
#
#     Parameters
#     ----------
#     axis : {0, 'index'}, default 0
#         Axis to direct sorting
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
#          orders.  If this is a list of bools, must match the length of
#          the by.
#     inplace : bool, default False
#          if True, perform operation in-place
#     kind : {'quicksort', 'mergesort', 'heapsort'}, default 'quicksort'
#          Choice of sorting algorithm. See also ndarray.np.sort for more
#          information.  `mergesort` is the only stable algorithm. For
#          DataFrames, this option is only applied when sorting on a single
# ...

# %%
change = change.dropna().sort_values(ascending=False)

# %%
change.head()
# Out:
# Country Name
# United Arab Emirates    15372.33
# Qatar                     482.04
# Equatorial Guinea         245.00
# Saudi Arabia              201.26
# Thailand                   80.60
# Name: percentage, dtype: float64

# %%
change.tail()
# Out:
# Country Name
# Belgium           0.03
# Hungary          -0.09
# Sweden           -0.10
# Luxembourg       -0.12
# United Kingdom   -0.22
# Name: percentage, dtype: float64

# %%
change.hist()

# %%
change.plot(kind='bar', figsize=(60, 26))

# %%
change.iloc[10:].plot(kind='bar', figsize=(60, 26))

# %%
countries = pd.read_excel('../Data/co2_emissions_v2.xls', sheetname='Metadata - Countries')

# %%
countries
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Lower middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Lower middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
sa_countries = countries[countries['Region'] == 'South Asia']

# %%
sa_countries
# Out:
#     Country Code      Region          IncomeGroup  \
# 1            AFG  South Asia           Low income
# 18           BGD  South Asia  Lower middle income
# 30           BTN  South Asia  Lower middle income
# 107          IND  South Asia  Lower middle income
# 135          LKA  South Asia  Lower middle income
# 149          MDV  South Asia  Upper middle income
# 175          NPL  South Asia           Low income
# 181          PAK  South Asia  Lower middle income
#
#                                           SpecialNotes    TableName
# 1    Fiscal year end: March 20; reporting period fo...  Afghanistan
# 18   Fiscal year end: June 30; reporting period for...   Bangladesh
# 30                                                 NaN       Bhutan
# 107  Fiscal year end: March 31; reporting period fo...        India
# 135  Bureau of Census and Statistics revised nation...    Sri Lanka
# 149                                                NaN     Maldives
# ...

# %%
sa_countries['TableName']
# Out:
# 1      Afghanistan
# 18      Bangladesh
# 30          Bhutan
# 107          India
# 135      Sri Lanka
# 149       Maldives
# 175          Nepal
# 181       Pakistan
# Name: TableName, dtype: object

# %%
dir(co2em.index)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__inv__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmul__',
#  '__rpow__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__unicode__',
#  '__weakref__',
#  '__xor__',
# ...

# %%
help(co2em.index.isin)
# Out:
# Help on method isin in module pandas.core.indexes.base:
#
# isin(values, level=None) method of pandas.core.indexes.base.Index instance
#     Compute boolean array of whether each index value is found in the
#     passed set of values.
#
#     Parameters
#     ----------
#     values : set or list-like
#         Sought values.
#
#         .. versionadded:: 0.18.1
#
#         Support for values as a set
#
#     level : str or int, optional
#         Name or position of the index level to use (if the index is a
#         MultiIndex).
#
#     Notes
#     -----
#     If `level` is specified:
#
#     - if it is the name of one *and only one* index level, use that level;
#     - otherwise it should be a number indicating level position.
#
#     Returns
#     -------
#     is_contained : ndarray (boolean dtype)

# %%
co2em.index.isin(sa_countries['TableName'])
# Out:
# array([False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
# ...

# %%
sa_countries['TableName'].values
# Out:
# array(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Sri Lanka',
#        'Maldives', 'Nepal', 'Pakistan'], dtype=object)

# %%
co2em.index.isin(sa_countries['TableName'].values)
# Out:
# array([False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
# ...

# %%
co2em.index.isin(['Nepal'])
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
co2em.index[co2em.index.isin(sa_countries['TableName'])]
# Out:
# Index(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Sri Lanka', 'Maldives',
#        'Nepal', 'Pakistan'],
#       dtype='object', name='Country Name')

# %%
co2em.index[co2em.index.isin(sa_countries['TableName'])].values
# Out:
# array(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Sri Lanka',
#        'Maldives', 'Nepal', 'Pakistan'], dtype=object)

# %%
co2em.loc[co2em.index[co2em.index.isin(sa_countries['TableName'])].values]
# Out:
#                     1960        1961        1962        1963        1964  \
# Country Name
# Afghanistan      414.371     491.378     689.396     707.731     839.743
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# Bhutan               NaN         NaN         NaN         NaN         NaN
# India         120581.961  130402.187  143467.708  154083.673  150647.694
# Sri Lanka       2258.872    2335.879    2563.233    2533.897    2273.540
# Maldives             NaN         NaN         NaN         NaN         NaN
# Nepal             80.674      80.674      88.008      99.009     150.347
# Pakistan       14154.620   14656.999   16105.464   18514.683   19035.397
#
#                     1965        1966        1967        1968        1969  \
# Country Name
# Afghanistan     1008.425    1092.766    1283.450    1224.778     942.419
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...

# %%
co2em.loc[sa_countries['TableName'].values]
# Out:
#                     1960        1961        1962        1963        1964  \
# Country Name
# Afghanistan      414.371     491.378     689.396     707.731     839.743
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# Bhutan               NaN         NaN         NaN         NaN         NaN
# India         120581.961  130402.187  143467.708  154083.673  150647.694
# Sri Lanka       2258.872    2335.879    2563.233    2533.897    2273.540
# Maldives             NaN         NaN         NaN         NaN         NaN
# Nepal             80.674      80.674      88.008      99.009     150.347
# Pakistan       14154.620   14656.999   16105.464   18514.683   19035.397
#
#                     1965        1966        1967        1968        1969  \
# Country Name
# Afghanistan     1008.425    1092.766    1283.450    1224.778     942.419
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...
