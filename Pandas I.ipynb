# %% [markdown]
# # Pandas
# ---
#
# Pandas is a data analysis tool, built on top of numpy.

# %%
import pandas as pd

# %%
names = ["Nepal", "India", "Bhutan"]
codes = [977, 81, 123]

# %%
list(zip(names, codes))
# Out:
# [('Nepal', 977), ('India', 81), ('Bhutan', 123)]

# %% [markdown]
# **zip: ** *zip creates collection of tuples out of each elements of given lists*

# %%
zip([1, 2, 3], [11, 12, 13], [21, 22, 23])

# %%
list(zip([1, 2, 3], [11, 12, 13], [21, 22, 23]))
# Out:
# [(1, 11, 21), (2, 12, 22), (3, 13, 23)]

# %% [markdown]
# *We create a dataset with names and codes*

# %%
dataset = list(zip(names, codes))

# %%
dataset
# Out:
# [('Nepal', 977), ('India', 81), ('Bhutan', 123)]

# %% [markdown]
# **Now we create a dataframe**

# %% [markdown]
# Dataframe is generally a tabular data with rows and columns ( similar to that of excel ).

# %%
df = pd.DataFrame(data=dataset, columns=["Name", "Code"])

# %%
df
# Out:
#      Name  Code
# 0   Nepal   977
# 1   India    81
# 2  Bhutan   123

# %% [markdown]
# *Here, each row defines a unique set of observation or condition, while each column defines parameters for observations*
#
# *In above dataframe, Name and Code are parameters we are using to define a country and each row i.e Nepal and 977 collectively gives us unique set*
#
# *__0__, __1__ .. are called index in pandas, they are generated while creating a dataframe*

# %% [markdown]
# *Let's create a large dataset*

# %%
import numpy as np

# %%
names = ['Bob', 'Jessica', 'Mary', 'John', 'Mel']

# %%
np.random.randint(low=0, high=len(names))
# Out:
# 3

# %%
random_names = [names[np.random.randint(low=0, high=len(names))] 
                for i in range(1000)]

# %%
random_names[:10]
# Out:
# ['Jessica',
#  'John',
#  'Jessica',
#  'John',
#  'Mary',
#  'Bob',
#  'John',
#  'Bob',
#  'Bob',
#  'Mel']

# %%
ages = [np.random.randint(low=1, high=100) for i in range(1000)]

# %%
ages[:10]
# Out:
# [80, 20, 13, 7, 31, 71, 23, 59, 43, 82]

# %%
df = pd.DataFrame(list(zip(random_names, ages)), 
                  columns=["Name", "Age"])

# %%
df
# Out:
#         Name  Age
# 0    Jessica   80
# 1       John   20
# 2    Jessica   13
# 3       John    7
# 4       Mary   31
# 5        Bob   71
# 6       John   23
# 7        Bob   59
# 8        Bob   43
# 9        Mel   82
# 10      Mary   63
# 11       Bob   15
# 12      John    5
# 13   Jessica   56
# 14       Bob   64
# 15   Jessica   75
# 16   Jessica    5
# 17       Bob   80
# 18      Mary   95
# 19      Mary   41
# 20       Bob   34
# 21       Mel   14
# 22       Bob   26
# 23      Mary   26
# 24   Jessica   89
# 25      Mary   78
# 26   Jessica   21
# 27      Mary   19
# 28      Mary    5
# 29      John   76
# ..       ...  ...
# 970      Mel   92
# 971      Bob   72
# 972     John   67
# 973     John   24
# 974     Mary   22
# 975     John   46
# 976      Bob    6
# 977     Mary   73
# 978      Bob   58
# 979     John   99
# 980      Mel    6
# 981     Mary   12
# 982      Bob   83
# 983     Mary   62
# 984      Mel   18
# 985      Bob   90
# 986     Mary   14
# 987     John   29
# 988  Jessica   32
# 989      Bob   91
# 990     Mary   85
# 991     John   81
# 992     John   97
# 993     Mary   73
# 994      Bob   52
# 995  Jessica   67
# 996      Bob   71
# 997     Mary   16
# 998     John   40
# 999     Mary   32
#
# [1000 rows x 2 columns]

# %% [markdown]
# **Overview of data**

# %% [markdown]
# *show first 5 rows*

# %%
df.head()
# Out:
#       Name  Age
# 0  Jessica   80
# 1     John   20
# 2  Jessica   13
# 3     John    7
# 4     Mary   31

# %% [markdown]
# *or 10*

# %%
df.head(10)
# Out:
#       Name  Age
# 0  Jessica   80
# 1     John   20
# 2  Jessica   13
# 3     John    7
# 4     Mary   31
# 5      Bob   71
# 6     John   23
# 7      Bob   59
# 8      Bob   43
# 9      Mel   82

# %% [markdown]
# *show last 5 rows*

# %%
df.tail()
# Out:
#         Name  Age
# 995  Jessica   67
# 996      Bob   71
# 997     Mary   16
# 998     John   40
# 999     Mary   32

# %% [markdown]
# *or 10*

# %%
df.tail(10)
# Out:
#         Name  Age
# 990     Mary   85
# 991     John   81
# 992     John   97
# 993     Mary   73
# 994      Bob   52
# 995  Jessica   67
# 996      Bob   71
# 997     Mary   16
# 998     John   40
# 999     Mary   32

# %% [markdown]
# ### Selecting rows and columns

# %% [markdown]
# **select single column from dataframe**

# %%
df["Name"]
# Out:
# 0      Jessica
# 1         John
# 2      Jessica
# 3         John
# 4         Mary
# 5          Bob
# 6         John
# 7          Bob
# 8          Bob
# 9          Mel
# 10        Mary
# 11         Bob
# 12        John
# 13     Jessica
# 14         Bob
# 15     Jessica
# 16     Jessica
# 17         Bob
# 18        Mary
# 19        Mary
# 20         Bob
# 21         Mel
# 22         Bob
# 23        Mary
# 24     Jessica
# 25        Mary
# 26     Jessica
# 27        Mary
# 28        Mary
# 29        John
#         ...
# 970        Mel
# 971        Bob
# 972       John
# 973       John
# 974       Mary
# 975       John
# 976        Bob
# 977       Mary
# 978        Bob
# 979       John
# 980        Mel
# 981       Mary
# 982        Bob
# 983       Mary
# 984        Mel
# 985        Bob
# 986       Mary
# 987       John
# 988    Jessica
# 989        Bob
# 990       Mary
# 991       John
# 992       John
# 993       Mary
# 994        Bob
# 995    Jessica
# 996        Bob
# 997       Mary
# 998       John
# 999       Mary
# Name: Name, Length: 1000, dtype: object

# %% [markdown]
# *Note: such selection which gave us rows of a single column, are called Series in pandas*

# %% [markdown]
# **Select multiple columns from dataframe**

# %%
df[["Name", "Age"]].head()
# Out:
#       Name  Age
# 0  Jessica   80
# 1     John   20
# 2  Jessica   13
# 3     John    7
# 4     Mary   31

# %% [markdown]
# *we are selecting multiple columns with list of columns ["Name", "Age"]*

# %% [markdown]
# **Select row from dataframe**

# %% [markdown]
# *Select from index*

# %%
# donot use this: deprecated
df.ix[0]
# Out:
# Name    Jessica
# Age          80
# Name: 0, dtype: object

# %% [markdown]
# > index can be either integers as above or any string, depends on dataframe

# %% [markdown]
# *Select from location*

# %%
df.iloc[0]
# Out:
# Name    Jessica
# Age          80
# Name: 0, dtype: object

# %% [markdown]
# > it is integer based location

# %% [markdown]
# *Select from labelled location*

# %%
df.loc[0]
# Out:
# Name    Jessica
# Age          80
# Name: 0, dtype: object

# %% [markdown]
# *Slicing based selection*

# %%
df.loc[0:6]
# Out:
#       Name  Age
# 0  Jessica   80
# 1     John   20
# 2  Jessica   13
# 3     John    7
# 4     Mary   31
# 5      Bob   71
# 6     John   23

# %%
df.iloc[0:6]
# Out:
#       Name  Age
# 0  Jessica   80
# 1     John   20
# 2  Jessica   13
# 3     John    7
# 4     Mary   31
# 5      Bob   71

# %% [markdown]
# **Behavior of loc and iloc**

# %%
# let's create a new dataframe with selected rows
ndf = df.loc[10:20]

# %%
ndf
# Out:
#        Name  Age
# 10     Mary   63
# 11      Bob   15
# 12     John    5
# 13  Jessica   56
# 14      Bob   64
# 15  Jessica   75
# 16  Jessica    5
# 17      Bob   80
# 18     Mary   95
# 19     Mary   41
# 20      Bob   34

# %%
ndf.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [0] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-45edce31b728> in <module>()
# ----> 1 ndf.loc[0]
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1440                 raise
#    1441             except:
# -> 1442                 error()
#    1443
#    1444         return True
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#    1431             try:
#
# KeyError: 'the label [0] is not in the [index]'

# %%
ndf.iloc[0]
# Out:
# Name    Mary
# Age       63
# Name: 10, dtype: object

# %%
ndf.loc[10]
# Out:
# Name    Mary
# Age       63
# Name: 10, dtype: object

# %%
mdf = pd.DataFrame([('Apple', 42, 56), ('Orange', 42, 56), 
                    ('Pineapple', 42, 56), ('Lime', 42, 56)], 
                   columns=["Name", "Price", "Qty"])

# %%
mdf = mdf.set_index(["Name"])

# %%
mdf
# Out:
#            Price  Qty
# Name
# Apple         42   56
# Orange        42   56
# Pineapple     42   56
# Lime          42   56

# %%
mdf.iloc[0]
# Out:
# Price    42
# Qty      56
# Name: Apple, dtype: int64

# %%
mdf.loc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-ea50d249be70> in <module>()
# ----> 1 mdf.loc[0]
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1430
#    1431             try:
# -> 1432                 key = self._convert_scalar_indexer(key, axis)
#    1433                 if not ax.contains(key):
#    1434                     error()
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
#     234         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     235         # a scalar
# --> 236         return ax._convert_scalar_indexer(key, kind=self.name)
#     237
#     238     def _convert_slice_indexer(self, key, axis):
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    1333             elif kind in ['loc'] and is_integer(key):
#    1334                 if not self.holds_integer():
# -> 1335                     return self._invalid_indexer('label', key)
#    1336
#    1337         return key
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    1517                         "indexers [{key}] of {kind}".format(
#    1518                             form=form, klass=type(self), key=key,
# -> 1519                             kind=type(key)))
#    1520
#    1521     def get_duplicates(self):
#
# TypeError: cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [0] of <class 'int'>

# %%
mdf.loc["Apple"]
# Out:
# Price    42
# Qty      56
# Name: Apple, dtype: int64

# %%
mdf.iloc["Apple"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-5c540561061a> in <module>()
# ----> 1 mdf.iloc["Apple"]
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1740         # a single integer
#    1741         else:
# -> 1742             key = self._convert_scalar_indexer(key, axis)
#    1743
#    1744             if not is_integer(key):
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_scalar_indexer(self, key, axis)
#     234         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     235         # a scalar
# --> 236         return ax._convert_scalar_indexer(key, kind=self.name)
#     237
#     238     def _convert_slice_indexer(self, key, axis):
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    1306
#    1307         if kind == 'iloc':
# -> 1308             return self._validate_indexer('positional', key, kind)
#    1309
#    1310         if len(self) and not isinstance(self, ABCMultiIndex,):
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _validate_indexer(self, form, key, kind)
#    3386             pass
#    3387         elif kind in ['iloc', 'getitem']:
# -> 3388             self._invalid_indexer(form, key)
#    3389         return key
#    3390
#
# /usr/local/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    1517                         "indexers [{key}] of {kind}".format(
#    1518                             form=form, klass=type(self), key=key,
# -> 1519                             kind=type(key)))
#    1520
#    1521     def get_duplicates(self):
#
# TypeError: cannot do positional indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [Apple] of <class 'str'>

# %% [markdown]
# *In above 3 cells, __loc__ is trying to access by index __0__, which is not present in our new dataframe while __iloc__ fetched 1st row or 0th data from our new dataframe*

# %% [markdown]
# **Silicing by rows and columns**

# %%
# get all data from 0 to 6 row and column "Age"
df.loc[0:6, "Age"]
# Out:
# 0    80
# 1    20
# 2    13
# 3     7
# 4    31
# 5    71
# 6    23
# Name: Age, dtype: int64

# %%
# get all data from 0 to 6 and column "Name" to "Age"
df.loc[0:6, "Name": "Age"]
# Out:
#       Name  Age
# 0  Jessica   80
# 1     John   20
# 2  Jessica   13
# 3     John    7
# 4     Mary   31
# 5      Bob   71
# 6     John   23

# %%
# column slicing should be in sequential order to that 
# of columns of dataframe
df.loc[0:6, "Age": "Name"]
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# **Changing columns of dataframe**

# %%
df.columns = ["Name of people", "Age of people"]

# %%
df.head()
# Out:
#   Name of people  Age of people
# 0        Jessica             80
# 1           John             20
# 2        Jessica             13
# 3           John              7
# 4           Mary             31

# %% [markdown]
# **Filtering basics**

# %%
# get all people whose age is less than 10
df[df["Age of people"] < 10]
# Out:
#     Name of people  Age of people
# 3             John              7
# 12            John              5
# 16         Jessica              5
# 28            Mary              5
# 61             Mel              2
# 73         Jessica              7
# 91            Mary              8
# 104        Jessica              2
# 106           John              7
# 109            Bob              9
# 112            Bob              6
# 130            Mel              7
# 136        Jessica              1
# 140            Bob              3
# 142        Jessica              3
# 145            Bob              2
# 147        Jessica              3
# 154            Mel              4
# 159        Jessica              1
# 161        Jessica              1
# 187           Mary              4
# 209            Bob              4
# 221           Mary              2
# 225        Jessica              5
# 230           Mary              2
# 245           Mary              9
# 249           Mary              8
# 258           John              8
# 261            Mel              6
# 270            Bob              3
# ..             ...            ...
# 640            Mel              3
# 646            Mel              7
# 651           John              5
# 660            Mel              1
# 671            Bob              3
# 687            Mel              7
# 696            Bob              7
# 715        Jessica              3
# 723            Mel              7
# 728            Bob              9
# 731           Mary              8
# 734            Bob              3
# 769            Bob              3
# 771            Bob              1
# 786            Bob              9
# 787            Mel              8
# 801           Mary              1
# 807            Mel              1
# 827            Mel              2
# 829            Bob              1
# 846           Mary              4
# 851        Jessica              9
# 859           John              4
# 889            Bob              6
# 891            Mel              3
# 917            Mel              8
# 923            Bob              2
# 941           Mary              3
# 976            Bob              6
# 980            Mel              6
#
# [94 rows x 2 columns]

# %%
# get all people whose age is less than 10 or age is greater than 90
df[(df["Age of people"] < 10) | (df["Age of people"] > 90)]
# Out:
#     Name of people  Age of people
# 3             John              7
# 12            John              5
# 16         Jessica              5
# 18            Mary             95
# 28            Mary              5
# 42            John             98
# 61             Mel              2
# 73         Jessica              7
# 91            Mary              8
# 103            Bob             96
# 104        Jessica              2
# 106           John              7
# 109            Bob              9
# 112            Bob              6
# 118        Jessica             94
# 130            Mel              7
# 136        Jessica              1
# 140            Bob              3
# 142        Jessica              3
# 145            Bob              2
# 147        Jessica              3
# 150           John             95
# 154            Mel              4
# 156           Mary             95
# 159        Jessica              1
# 161        Jessica              1
# 187           Mary              4
# 193           John             98
# 194           Mary             92
# 199            Bob             97
# ..             ...            ...
# 821           John             95
# 827            Mel              2
# 829            Bob              1
# 831            Bob             99
# 837           Mary             94
# 846           Mary              4
# 851        Jessica              9
# 852           Mary             92
# 854            Mel             93
# 859           John              4
# 872           Mary             97
# 880           John             95
# 881           John             94
# 889            Bob              6
# 890            Mel             96
# 891            Mel              3
# 904           Mary             96
# 917            Mel              8
# 922            Bob             98
# 923            Bob              2
# 937           Mary             99
# 941           Mary              3
# 948        Jessica             97
# 965            Mel             93
# 970            Mel             92
# 976            Bob              6
# 979           John             99
# 980            Mel              6
# 989            Bob             91
# 992           John             97
#
# [177 rows x 2 columns]

# %%
# get mean
df.mean()
# Out:
# Age of people    49.009
# dtype: float64

# %%
# get max
df.max()
# Out:
# Name of people    Mel
# Age of people      99
# dtype: object

# %%
# get min
df.min()
# Out:
# Name of people    Bob
# Age of people       1
# dtype: object

# %%
# get median
df.median()
# Out:
# Age of people    48.0
# dtype: float64

# %%
# get standard deviation
df.std()
# Out:
# Age of people    28.37178
# dtype: float64

# %%
df.head()
# Out:
#   Name of people  Age of people
# 0        Jessica             80
# 1           John             20
# 2        Jessica             13
# 3           John              7
# 4           Mary             31

# %%
df.groupby("Name of people").mean()
# Out:
#                 Age of people
# Name of people
# Bob                 44.323529
# Jessica             51.481481
# John                53.302439
# Mary                49.321951
# Mel                 46.695431
