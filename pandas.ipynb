# %% [markdown]
# ## Pandas
# ---

# %%
from pandas import DataFrame

# %%
import pandas as pd

# %%
names = ["Nepal", "India", "Bhutan"]
codes = [977, 81, 123]

# %%
list(zip(names, codes))
# Out:
# [('Nepal', 977), ('India', 81), ('Bhutan', 123)]

# %%
dataset = list(zip(['John', 'Hari', 'Harry'], [12, 16, 14]))

# %%
dataset
# Out:
# [('John', 12), ('Hari', 16), ('Harry', 14)]

# %%
df = DataFrame(data=dataset, columns=["Name", "Age"])

# %%
df
# Out:
#     Name  Age
# 0   John   12
# 1   Hari   16
# 2  Harry   14

# %%
df.to_csv('test.csv', index=False)

# %%
import csv

# %%
import csv

with open('test2.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=['Name', 'Age'])
    writer.writerows([{'Name': 'John', 'Age': 12}])

# %%
_fp = open('test.csv', 'r')

# %%
_fp.read()
# Out:
# 'Name,Age\nJohn,12\nHari,16\nHarry,14\n'

# %%
_fp.read()
# Out:
# ''

# %%
_fp.seek(0)
# Out:
# 0

# %%
_fp.read()
# Out:
# 'Name,Age\nJohn,12\nHari,16\nHarry,14\n'

# %%
_fp.read()
# Out:
# ''

# %%
_fp.close()

# %%
df = pd.read_csv('nepal.csv', skiprows=3)

# %%
df
# Out:
#      Country Name Country Code  \
# 0           Nepal          NPL
# 1           Nepal          NPL
# 2           Nepal          NPL
# 3           Nepal          NPL
# 4           Nepal          NPL
# 5           Nepal          NPL
# 6           Nepal          NPL
# 7           Nepal          NPL
# 8           Nepal          NPL
# 9           Nepal          NPL
# 10          Nepal          NPL
# 11          Nepal          NPL
# 12          Nepal          NPL
# 13          Nepal          NPL
# 14          Nepal          NPL
# 15          Nepal          NPL
# 16          Nepal          NPL
# 17          Nepal          NPL
# 18          Nepal          NPL
# 19          Nepal          NPL
# 20          Nepal          NPL
# 21          Nepal          NPL
# 22          Nepal          NPL
# 23          Nepal          NPL
# 24          Nepal          NPL
# 25          Nepal          NPL
# 26          Nepal          NPL
# 27          Nepal          NPL
# 28          Nepal          NPL
# ...

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
# 1961              float64
# 1962              float64
# 1963              float64
# 1964              float64
# 1965              float64
# 1966              float64
# 1967              float64
# 1968              float64
# 1969              float64
# 1970              float64
# 1971              float64
# 1972              float64
# 1973              float64
# 1974              float64
# 1975              float64
# 1976              float64
# 1977              float64
# 1978              float64
# 1979              float64
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
#                    ...
# 1987              float64
# 1988              float64
# 1989              float64
# 1990              float64
# ...

# %%
sorted_df = df.sort_values(["Indicator Name"], ascending=False)

# %%
sorted_df
# Out:
#      Country Name Country Code  \
# 870         Nepal          NPL
# 869         Nepal          NPL
# 868         Nepal          NPL
# 871         Nepal          NPL
# 1023        Nepal          NPL
# 1290        Nepal          NPL
# 1011        Nepal          NPL
# 1009        Nepal          NPL
# 1007        Nepal          NPL
# 1006        Nepal          NPL
# 1005        Nepal          NPL
# 1010        Nepal          NPL
# 480         Nepal          NPL
# 439         Nepal          NPL
# 1288        Nepal          NPL
# 1156        Nepal          NPL
# 1157        Nepal          NPL
# 1155        Nepal          NPL
# 1154        Nepal          NPL
# 1153        Nepal          NPL
# 1152        Nepal          NPL
# 1269        Nepal          NPL
# 563         Nepal          NPL
# 1044        Nepal          NPL
# 183         Nepal          NPL
# 1119        Nepal          NPL
# 1118        Nepal          NPL
# 427         Nepal          NPL
# 1310        Nepal          NPL
# ...

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0        Nepal          NPL
# 1        Nepal          NPL
# 2        Nepal          NPL
# 3        Nepal          NPL
# 4        Nepal          NPL
#
#                                       Indicator Name     Indicator Code  1960  \
# 0                   Agricultural machinery, tractors     AG.AGR.TRAC.NO   NaN
# 1  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS   NaN
# 2  Fertilizer consumption (kilograms per hectare ...     AG.CON.FERT.ZS   NaN
# 3                         Agricultural land (sq. km)     AG.LND.AGRI.K2   NaN
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS   NaN
#
#            1961          1962          1963          1964          1965  \
# 0    180.000000    190.000000    200.000000    215.000000    225.000000
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# ...

# %%
df.tail()
# Out:
#      Country Name Country Code  \
# 1414        Nepal          NPL
# 1415        Nepal          NPL
# 1416        Nepal          NPL
# 1417        Nepal          NPL
# 1418        Nepal          NPL
#
#                                          Indicator Name Indicator Code  1960  \
# 1414                    Mobile account (% age 15+) [w2]    WP15163_4.1   NaN
# 1415              Mobile account, male (% age 15+) [w2]    WP15163_4.2   NaN
# 1416            Mobile account, female (% age 15+) [w2]    WP15163_4.3   NaN
# 1417  Mobile account, income, poorest 40% (% ages 15...    WP15163_4.8   NaN
# 1418  Mobile account, income, richest 60% (% ages 15...    WP15163_4.9   NaN
#
#       1961  1962  1963  1964  1965     ...       2007  2008  2009  2010  2011  \
# 1414   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN   NaN   NaN
# 1415   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN   NaN   NaN
# ...

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
# ...

# %%
df.loc[2:9:2]
# Out:
#   Country Name Country Code  \
# 2        Nepal          NPL
# 4        Nepal          NPL
# 6        Nepal          NPL
# 8        Nepal          NPL
#
#                                       Indicator Name     Indicator Code  1960  \
# 2  Fertilizer consumption (kilograms per hectare ...     AG.CON.FERT.ZS   NaN
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS   NaN
# 6                  Arable land (hectares per person)  AG.LND.ARBL.HA.PC   NaN
# 8            Land under cereal production (hectares)     AG.LND.CREL.HA   NaN
#
#            1961          1962          1963          1964          1965  \
# 2           NaN           NaN           NaN           NaN           NaN
# 4  2.484615e+01  2.484615e+01  2.491608e+01  2.484615e+01  2.484615e+01
# 6  1.767962e-01  1.740377e-01  1.722211e-01  1.684703e-01  1.656120e-01
# 8  1.715000e+06  1.724500e+06  1.725500e+06  1.742000e+06  1.786000e+06
#
# ...

# %%
df["1961"]
# Out:
# 0       1.800000e+02
# 1                NaN
# 2                NaN
# 3       3.553000e+04
# 4       2.484615e+01
# 5       1.806000e+06
# 6       1.767962e-01
# 7       1.262937e+01
# 8       1.715000e+06
# 9       1.748252e-01
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19      1.430000e+05
# 20               NaN
# 21               NaN
# 22      9.966777e-01
# 23      3.167000e+06
# 24      2.821000e+01
# 25      2.840000e+01
# 26      3.001000e+01
# 27      1.471800e+05
# 28      1.846600e+03
# 29               NaN
#             ...
# 1389             NaN
# 1390             NaN
# 1391             NaN
# 1392             NaN
# 1393             NaN
# 1394             NaN
# 1395             NaN
# 1396             NaN
# 1397             NaN
# 1398             NaN
# 1399             NaN
# 1400             NaN
# ...

# %%
df["1961"].max()
# Out:
# 105861079000.0

# %%
df["1961"].min()
# Out:
# -3.1011450381679397

# %%
df["1961"].mean()
# Out:
# 1025478594.7166033

# %%
df["1961"].count()
# Out:
# 124

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
df["2013"].plot()
