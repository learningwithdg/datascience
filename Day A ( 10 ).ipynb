# %% [markdown]
# # Day 10
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# !dir
# Out:
# API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# API_EN.ATM.CO2E.KT_DS2_en_csv_v2.zip
# cat.jpg
# datasets.h5
# data.sqlite3
# Day\ 1.ipynb
# Day\ 2.ipynb
# Day\ 3.ipynb
# Day\ 4.ipynb
# Day\ 5.ipynb
# Day\ 6.ipynb
# Day\ 7.ipynb
# Day\ 8.ipynb
# Day\ 9.ipynb
# Day\ A\ (\ 10\ ).ipynb
# environment.yml
# LICENSE
# Matplotlib\ II.ipynb
# Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# Metadata_Indicator_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# names.csv
# Numpy\ III\ and\ Matplotlib\ I.ipynb
# Numpy\ II.ipynb
# Numpy\ I.ipynb
# Pandas\ III.ipynb
# Pandas\ II.ipynb
# Pandas\ I.ipynb
# Pandas\ IV.ipynb
# Problems
# README.md
# References
# uni01-numpy-session.ipynb
# unit-01-data-session.ipynb
# unit-03-numpy.ipynb

# %%
pd.read_csv('Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Upper middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Lower middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
pd.read_csv('Metadata_Indicator_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
#    INDICATOR_CODE      INDICATOR_NAME  \
# 0  EN.ATM.CO2E.KT  CO2 emissions (kt)
#
#                                          SOURCE_NOTE  \
# 0  Carbon dioxide emissions are those stemming fr...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  Carbon Dioxide Information Analysis Center, En...         NaN

# %%
df = pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-7-dee1dd4fe172> in <module>()
# ----> 1 df = pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
#
# ...

# %%
# !head API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# Out:
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2017-03-23",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016",
# "Aruba","ABW","CO2 emissions (kt)","EN.ATM.CO2E.KT","","","","","","","","","","","","","","","","","","","","","","","","","","","179.683","447.374","612.389","649.059","1730.824","1771.161","1558.475","1602.479","1595.145","1609.813","1617.147","1650.15","1712.489","1749.159","2321.211","2357.881","2372.549","2416.553","2420.22","2497.227","2497.227","2592.569","2508.228","2522.896","2456.89","2438.555","1301.785","876.413","","","",
# ...

# %%
df = pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv', skiprows=3)

# %%
df.head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 2  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 3       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 4      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
#
#        1961      1962      1963      1964      1965     ...            2008  \
# 0       NaN       NaN       NaN       NaN       NaN     ...        2508.228
# 1       NaN       NaN       NaN       NaN       NaN     ...         539.049
# 2   491.378   689.396   707.731   839.743  1008.425     ...        4217.050
# 3   454.708  1180.774  1151.438  1224.778  1188.108     ...       25709.337
# 4  2280.874  2464.224  2082.856  2016.850  2174.531     ...        4374.731
#
# ...

# %%
df[df["Country Name"] == 'Nepal']
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code    1960  \
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT  80.674
#
#        1961    1962    1963     1964     1965     ...           2008  \
# 176  80.674  88.008  99.009  150.347  179.683     ...       3421.311
#
#          2009      2010      2011      2012      2013  2014  2015  2016  \
# 176  4334.394  5056.793  5533.503  5845.198  6501.591   NaN   NaN   NaN
#
#      Unnamed: 61
# 176          NaN
#
# [1 rows x 62 columns]

# %%
ndf = df[df["Country Name"] == 'Nepal']

# %%
ndf.plot()df[df["Country Name"] == 'Nepal']df[df["Country Name"] == 'Nepal']
# Out:
# /home/idwaker/Shire/Anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2903: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=176.0, right=176.0
#   'left=%s, right=%s') % (left, right))

# %%
ndf.T
# Out:
#                                176
# Country Name                 Nepal
# Country Code                   NPL
# Indicator Name  CO2 emissions (kt)
# Indicator Code      EN.ATM.CO2E.KT
# 1960                        80.674
# 1961                        80.674
# 1962                        88.008
# 1963                        99.009
# 1964                       150.347
# 1965                       179.683
# 1966                       190.684
# 1967                       212.686
# 1968                       253.023
# 1969                       399.703
# 1970                       227.354
# 1971                       198.018
# 1972                       267.691
# 1973                       421.705
# 1974                       425.372
# 1975                       352.032
# 1976                       282.359
# 1977                       337.364
# 1978                        330.03
# 1979                        513.38
# 1980                       542.716
# 1981                       454.708
# ...

# %%
ndf.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e28cb1f8881e> in <module>()
# ----> 1 ndf.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])
#
# /home/idwaker/Shire/Anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# /home/idwaker/Shire/Anaconda3/lib/python3.6/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
ndf
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code    1960  \
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT  80.674
#
#        1961    1962    1963     1964     1965     ...           2008  \
# 176  80.674  88.008  99.009  150.347  179.683     ...       3421.311
#
#          2009      2010      2011      2012      2013  2014  2015  2016  \
# 176  4334.394  5056.793  5533.503  5845.198  6501.591   NaN   NaN   NaN
#
#      Unnamed: 61
# 176          NaN
#
# [1 rows x 62 columns]

# %%
ndf.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], axis=1)
# Out:
#        1960    1961    1962    1963     1964     1965     1966     1967  \
# 176  80.674  80.674  88.008  99.009  150.347  179.683  190.684  212.686
#
#         1968     1969     ...           2008      2009      2010      2011  \
# 176  253.023  399.703     ...       3421.311  4334.394  5056.793  5533.503
#
#          2012      2013  2014  2015  2016  Unnamed: 61
# 176  5845.198  6501.591   NaN   NaN   NaN          NaN
#
# [1 rows x 58 columns]

# %%
ndf
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code    1960  \
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT  80.674
#
#        1961    1962    1963     1964     1965     ...           2008  \
# 176  80.674  88.008  99.009  150.347  179.683     ...       3421.311
#
#          2009      2010      2011      2012      2013  2014  2015  2016  \
# 176  4334.394  5056.793  5533.503  5845.198  6501.591   NaN   NaN   NaN
#
#      Unnamed: 61
# 176          NaN
#
# [1 rows x 62 columns]

# %%
ndf.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], axis=1, 
         inplace=True)
# Out:
# /home/idwaker/Shire/Anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
ndf
# Out:
#        1960    1961    1962    1963     1964     1965     1966     1967  \
# 176  80.674  80.674  88.008  99.009  150.347  179.683  190.684  212.686
#
#         1968     1969     ...           2008      2009      2010      2011  \
# 176  253.023  399.703     ...       3421.311  4334.394  5056.793  5533.503
#
#          2012      2013  2014  2015  2016  Unnamed: 61
# 176  5845.198  6501.591   NaN   NaN   NaN          NaN
#
# [1 rows x 58 columns]

# %%
ndf = ndf.T

# %%
ndf
# Out:
#                   176
# 1960           80.674
# 1961           80.674
# 1962           88.008
# 1963           99.009
# 1964          150.347
# 1965          179.683
# 1966          190.684
# 1967          212.686
# 1968          253.023
# 1969          399.703
# 1970          227.354
# 1971          198.018
# 1972          267.691
# 1973          421.705
# 1974          425.372
# 1975          352.032
# 1976          282.359
# 1977          337.364
# 1978          330.030
# 1979          513.380
# 1980          542.716
# 1981          454.708
# 1982          443.707
# 1983          495.045
# 1984          704.064
# 1985          678.395
# 1986          704.064
# 1987          872.746
# 1988          993.757
# 1989          913.083
# 1990          634.391
# 1991          960.754
# 1992         1331.121
# 1993         1466.800
# 1994         1697.821
# 1995         2035.185
# 1996         2486.226
# 1997         2783.253
# 1998         2251.538
# 1999         3219.626
# ...

# %%
ndf.columns = ['Emission']

# %%
ndf
# Out:
#              Emission
# 1960           80.674
# 1961           80.674
# 1962           88.008
# 1963           99.009
# 1964          150.347
# 1965          179.683
# 1966          190.684
# 1967          212.686
# 1968          253.023
# 1969          399.703
# 1970          227.354
# 1971          198.018
# 1972          267.691
# 1973          421.705
# 1974          425.372
# 1975          352.032
# 1976          282.359
# 1977          337.364
# 1978          330.030
# 1979          513.380
# 1980          542.716
# 1981          454.708
# 1982          443.707
# 1983          495.045
# 1984          704.064
# 1985          678.395
# 1986          704.064
# 1987          872.746
# 1988          993.757
# 1989          913.083
# 1990          634.391
# 1991          960.754
# 1992         1331.121
# 1993         1466.800
# 1994         1697.821
# 1995         2035.185
# 1996         2486.226
# 1997         2783.253
# 1998         2251.538
# 1999         3219.626
# ...

# %%
ndf.dropna(inplace=True)

# %%
ndf
# Out:
#       Emission
# 1960    80.674
# 1961    80.674
# 1962    88.008
# 1963    99.009
# 1964   150.347
# 1965   179.683
# 1966   190.684
# 1967   212.686
# 1968   253.023
# 1969   399.703
# 1970   227.354
# 1971   198.018
# 1972   267.691
# 1973   421.705
# 1974   425.372
# 1975   352.032
# 1976   282.359
# 1977   337.364
# 1978   330.030
# 1979   513.380
# 1980   542.716
# 1981   454.708
# 1982   443.707
# 1983   495.045
# 1984   704.064
# 1985   678.395
# 1986   704.064
# 1987   872.746
# 1988   993.757
# 1989   913.083
# 1990   634.391
# 1991   960.754
# 1992  1331.121
# 1993  1466.800
# 1994  1697.821
# 1995  2035.185
# 1996  2486.226
# 1997  2783.253
# 1998  2251.538
# 1999  3219.626
# 2000  3069.279
# 2001  3267.297
# 2002  2625.572
# 2003  2841.925
# 2004  2669.576
# 2005  3083.947
# 2006  2563.233
# 2007  2614.571
# 2008  3421.311
# 2009  4334.394
# 2010  5056.793
# 2011  5533.503
# 2012  5845.198
# 2013  6501.591

# %%
ndf.plot()

# %%
ndf.index
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
country_df = pd.read_csv('Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')

# %%
country_df.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Upper middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...        Aruba         NaN
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan         NaN
# 2  April 2013 database update: Based on IMF data,...       Angola         NaN
# 3                                                NaN      Albania         NaN
# 4  The base year has changed to 2000. Price valua...      Andorra         NaN

# %%
sa_countries = country_df[country_df['Region'] == 'South Asia']['Country Code']

# %%
sa_countries
# Out:
# 1      AFG
# 18     BGD
# 30     BTN
# 107    IND
# 136    LKA
# 150    MDV
# 176    NPL
# 182    PAK
# Name: Country Code, dtype: object

# %%
df.head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 2  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 3       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 4      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
#
#        1961      1962      1963      1964      1965     ...            2008  \
# 0       NaN       NaN       NaN       NaN       NaN     ...        2508.228
# 1       NaN       NaN       NaN       NaN       NaN     ...         539.049
# 2   491.378   689.396   707.731   839.743  1008.425     ...        4217.050
# 3   454.708  1180.774  1151.438  1224.778  1188.108     ...       25709.337
# 4  2280.874  2464.224  2082.856  2016.850  2174.531     ...        4374.731
#
# ...

# %%
df[df['Country Code'].isin(sa_countries.values)]
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code        1960  \
# 2    Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# 18    Bangladesh          BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 30        Bhutan          BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 106        India          IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# 136    Sri Lanka          LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# 150     Maldives          MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# 182     Pakistan          PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#            1961        1962        1963        1964        1965     ...       \
# 2       491.378     689.396     707.731     839.743    1008.425     ...
# 18          NaN         NaN         NaN         NaN         NaN     ...
# ...

# %%
sdf = df[df['Country Code'].isin(sa_countries.values)]

# %%
sdf.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], axis=1)
# Out:
#            1960        1961        1962        1963        1964        1965  \
# 2       414.371     491.378     689.396     707.731     839.743    1008.425
# 18          NaN         NaN         NaN         NaN         NaN         NaN
# 30          NaN         NaN         NaN         NaN         NaN         NaN
# 106  120581.961  130402.187  143467.708  154083.673  150647.694  165972.087
# 136    2258.872    2335.879    2563.233    2533.897    2273.540    2658.575
# 150         NaN         NaN         NaN         NaN         NaN         NaN
# 176      80.674      80.674      88.008      99.009     150.347     179.683
# 182   14154.620   14656.999   16105.464   18514.683   19035.397   19974.149
#
#            1966        1967        1968        1969     ...              2008  \
# 2      1092.766    1283.450    1224.778     942.419     ...          4217.050
# 18          NaN         NaN         NaN         NaN     ...         49559.505
# ...

# %%
sdf.head()
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code        1960  \
# 2    Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# 18    Bangladesh          BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 30        Bhutan          BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 106        India          IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# 136    Sri Lanka          LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
#
#            1961        1962        1963        1964        1965     ...       \
# 2       491.378     689.396     707.731     839.743    1008.425     ...
# 18          NaN         NaN         NaN         NaN         NaN     ...
# 30          NaN         NaN         NaN         NaN         NaN     ...
# 106  130402.187  143467.708  154083.673  150647.694  165972.087     ...
# 136    2335.879    2563.233    2533.897    2273.540    2658.575     ...
#
# ...

# %%
sdf.set_index('Country Name')
# Out:
#              Country Code      Indicator Name  Indicator Code        1960  \
# Country Name
# Afghanistan           AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# Bangladesh            BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Bhutan                BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# India                 IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# Sri Lanka             LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# Maldives              MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Nepal                 NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# Pakistan              PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#                     1961        1962        1963        1964        1965  \
# Country Name
# Afghanistan      491.378     689.396     707.731     839.743    1008.425
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...

# %%
sdf
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code        1960  \
# 2    Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# 18    Bangladesh          BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 30        Bhutan          BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 106        India          IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# 136    Sri Lanka          LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# 150     Maldives          MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# 182     Pakistan          PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#            1961        1962        1963        1964        1965     ...       \
# 2       491.378     689.396     707.731     839.743    1008.425     ...
# 18          NaN         NaN         NaN         NaN         NaN     ...
# ...

# %%
sdf.set_index('Country Name', inplace=True)

# %%
sdf
# Out:
#              Country Code      Indicator Name  Indicator Code        1960  \
# Country Name
# Afghanistan           AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# Bangladesh            BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Bhutan                BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# India                 IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# Sri Lanka             LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# Maldives              MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Nepal                 NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# Pakistan              PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#                     1961        1962        1963        1964        1965  \
# Country Name
# Afghanistan      491.378     689.396     707.731     839.743    1008.425
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...

# %%
sdf.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis=1, inplace=True)
# Out:
# /home/idwaker/Shire/Anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
sdf.head()
# Out:
#                     1960        1961        1962        1963        1964  \
# Country Name
# Afghanistan      414.371     491.378     689.396     707.731     839.743
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# Bhutan               NaN         NaN         NaN         NaN         NaN
# India         120581.961  130402.187  143467.708  154083.673  150647.694
# Sri Lanka       2258.872    2335.879    2563.233    2533.897    2273.540
#
#                     1965        1966        1967        1968        1969  \
# Country Name
# Afghanistan     1008.425    1092.766    1283.450    1224.778     942.419
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# Bhutan               NaN         NaN         NaN         NaN         NaN
# India         165972.087  171765.947  172238.990  187336.029  190724.337
# Sri Lanka       2658.575    2662.242    2948.268    3241.628    4319.726
#
# ...

# %%
sdf = sdf.T

# %%
sdf
# Out:
# Country Name  Afghanistan  Bangladesh   Bhutan        India  Sri Lanka  \
# 1960              414.371         NaN      NaN   120581.961   2258.872
# 1961              491.378         NaN      NaN   130402.187   2335.879
# 1962              689.396         NaN      NaN   143467.708   2563.233
# 1963              707.731         NaN      NaN   154083.673   2533.897
# 1964              839.743         NaN      NaN   150647.694   2273.540
# 1965             1008.425         NaN      NaN   165972.087   2658.575
# 1966             1092.766         NaN      NaN   171765.947   2662.242
# 1967             1283.450         NaN      NaN   172238.990   2948.268
# 1968             1224.778         NaN      NaN   187336.029   3241.628
# 1969              942.419         NaN      NaN   190724.337   4319.726
# 1970             1672.152         NaN    3.667   195143.072   3597.327
# 1971             1895.839         NaN    3.667   205869.047   3197.624
# ...

# %%
sdf.dropna(inplace=True)

# %%
sdf
# Out:
# Country Name  Afghanistan  Bangladesh   Bhutan        India  Sri Lanka  \
# 1972             1532.806    3509.319    3.667   217849.136   3542.322
# 1973             1639.149    4554.414    3.667   224343.393   3689.002
# 1974             1917.841    4660.757    3.667   231992.755   2933.600
# 1975             2126.860    4869.776    3.667   252201.592   2896.930
# 1976             1987.514    5570.173    3.667   263785.645   2805.255
# 1977             2390.884    5812.195    7.334   279051.366   2918.932
# 1978             2159.863    6017.547   11.001   283096.067   3450.647
# 1979             2240.537    6648.271   22.002   296891.321   3828.348
# 1980             1760.160    7638.361   22.002   314016.211   3410.310
# 1981             1983.847    7931.721   25.669   338838.134   4033.700
# 1982             2101.191    8599.115   33.003   349637.449   4499.409
# 1983             2522.896    8236.082   29.336   378669.088   4884.444
# ...

# %%
sdf.plot()

# %%
import seaborn as sns
sns.set()

# %%
sdf.plot()

# %%
sdf[['Bangladesh', 'Nepal', 'Pakistan', 'Bhutan']]
# Out:
# Country Name  Bangladesh     Nepal    Pakistan   Bhutan
# 1972            3509.319   267.691   18929.054    3.667
# 1973            4554.414   421.705   20036.488    3.667
# 1974            4660.757   425.372   21418.947    3.667
# 1975            4869.776   352.032   23219.444    3.667
# 1976            5570.173   282.359   22838.076    3.667
# 1977            5812.195   337.364   24389.217    7.334
# 1978            6017.547   330.030   26138.376   11.001
# 1979            6648.271   513.380   28250.568   22.002
# 1980            7638.361   542.716   32067.915   22.002
# 1981            7931.721   454.708   34400.127   25.669
# 1982            8599.115   443.707   37385.065   33.003
# 1983            8236.082   495.045   40303.997   29.336
# 1984            9123.496   704.064   42856.229   51.338
# 1985           10234.597   678.395   47175.955   62.339
# 1986           11463.042   704.064   49453.162   55.005
# 1987           11862.745   872.746   53534.533  102.676
# ...

# %%
sdf[['Maldives', 'Nepal', 'Sri Lanka', 'Bhutan']].plot()

# %%
sdf.plot(kind='bar')

# %% [markdown]
# ### Alternative method

# %%
df.head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 2  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 3       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 4      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
#
#        1961      1962      1963      1964      1965     ...            2008  \
# 0       NaN       NaN       NaN       NaN       NaN     ...        2508.228
# 1       NaN       NaN       NaN       NaN       NaN     ...         539.049
# 2   491.378   689.396   707.731   839.743  1008.425     ...        4217.050
# 3   454.708  1180.774  1151.438  1224.778  1188.108     ...       25709.337
# 4  2280.874  2464.224  2082.856  2016.850  2174.531     ...        4374.731
#
# ...

# %%
country_df.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Upper middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...        Aruba         NaN
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan         NaN
# 2  April 2013 database update: Based on IMF data,...       Angola         NaN
# 3                                                NaN      Albania         NaN
# 4  The base year has changed to 2000. Price valua...      Andorra         NaN

# %%
pd.merge(df, country_df).head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 2  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 3       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 4      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
#
#        1961      1962      1963      1964      1965     ...           2013  \
# 0       NaN       NaN       NaN       NaN       NaN     ...        876.413
# 1       NaN       NaN       NaN       NaN       NaN     ...        491.378
# 2   491.378   689.396   707.731   839.743  1008.425     ...      21268.600
# 3   454.708  1180.774  1151.438  1224.778  1188.108     ...      32463.951
# 4  2280.874  2464.224  2082.856  2016.850  2174.531     ...       4814.771
#
#    2014  2015  2016  Unnamed: 61                     Region  \
# ...

# %% [markdown]
# pd.merge(df, country_df, on='Country Name')

# %%
sdf.head()
# Out:
# Country Name  Afghanistan  Bangladesh  Bhutan       India  Sri Lanka  \
# 1972             1532.806    3509.319   3.667  217849.136   3542.322
# 1973             1639.149    4554.414   3.667  224343.393   3689.002
# 1974             1917.841    4660.757   3.667  231992.755   2933.600
# 1975             2126.860    4869.776   3.667  252201.592   2896.930
# 1976             1987.514    5570.173   3.667  263785.645   2805.255
#
# Country Name  Maldives    Nepal   Pakistan
# 1972             3.667  267.691  18929.054
# 1973             3.667  421.705  20036.488
# 1974             3.667  425.372  21418.947
# 1975             7.334  352.032  23219.444
# 1976            11.001  282.359  22838.076

# %%
sdf.columns
# Out:
# Index(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Sri Lanka', 'Maldives',
#        'Nepal', 'Pakistan'],
#       dtype='object', name='Country Name')

# %%
sdf.columns.difference(['India'])
# Out:
# Index(['Afghanistan', 'Bangladesh', 'Bhutan', 'Maldives', 'Nepal', 'Pakistan',
#        'Sri Lanka'],
#       dtype='object', name='Country Name')

# %%
sdf[sdf.columns.difference(['India', 'Pakistan'])]
# Out:
# Country Name  Afghanistan  Bangladesh   Bhutan  Maldives     Nepal  Sri Lanka
# 1972             1532.806    3509.319    3.667     3.667   267.691   3542.322
# 1973             1639.149    4554.414    3.667     3.667   421.705   3689.002
# 1974             1917.841    4660.757    3.667     3.667   425.372   2933.600
# 1975             2126.860    4869.776    3.667     7.334   352.032   2896.930
# 1976             1987.514    5570.173    3.667    11.001   282.359   2805.255
# 1977             2390.884    5812.195    7.334    14.668   337.364   2918.932
# 1978             2159.863    6017.547   11.001    22.002   330.030   3450.647
# 1979             2240.537    6648.271   22.002    29.336   513.380   3828.348
# 1980             1760.160    7638.361   22.002    44.004   542.716   3410.310
# 1981             1983.847    7931.721   25.669    47.671   454.708   4033.700
# 1982             2101.191    8599.115   33.003    47.671   443.707   4499.409
# ...

# %%
sdf.loc['2000':'2013']
# Out:
# Country Name  Afghanistan  Bangladesh   Bhutan        India  Sri Lanka  \
# 2000              773.737   27869.200  396.036  1031853.463  10238.264
# 2001              638.058   32456.617  385.035  1041152.975  10443.616
# 2002              883.747   33707.064  418.038  1054258.833  11056.005
# 2003             1026.760   35672.576  377.701  1099597.621  11078.007
# 2004              949.753   37704.094  308.028  1154320.262  12299.118
# 2005             1327.454   39478.922  396.036  1222563.132  12101.100
# 2006             1650.150   43541.958  392.369  1303717.509  11976.422
# 2007             2273.540   44407.370  392.369  1407607.286  12354.123
# 2008             4217.050   49559.505  421.705  1568379.567  12207.443
# 2009             6776.616   53824.226  388.702  1738645.711  13175.531
# 2010             8470.770   59992.120  487.711  1719690.988  13688.911
# 2011            12251.447   63571.112  733.400  1846763.539  15232.718
# ...

# %%
sdf.loc['2000':'2013'].sum()
# Out:
# Country Name
# Afghanistan    8.296221e+04
# Bangladesh     6.582155e+05
# Bhutan         6.798618e+03
# India          2.024181e+07
# Sri Lanka      1.781025e+05
# Maldives       1.052796e+04
# Nepal          5.342819e+04
# Pakistan       1.978658e+06
# dtype: float64

# %%
sdf.loc['2000':'2013'].sum(axis=1)
# Out:
# 2000    1181100.363
# 2001    1197088.483
# 2002    1217627.350
# 2003    1269995.777
# 2004    1340519.521
# 2005    1416188.066
# 2006    1510675.655
# 2007    1629325.107
# 2008    1798120.784
# 2009    1976865.032
# 2010    1969681.379
# 2011    2107047.199
# 2012    2293466.478
# 2013    2302798.993
# dtype: float64

# %%
sdf.loc['2000':'2013'].sum().plot(kind='bar')

# %%
sdf2 = sdf.loc['2000':'2013']

# %%
sdf2 = sdf2[sdf2.columns.difference(['India'])]

# %%
sdf2
# Out:
# Country Name  Afghanistan  Bangladesh   Bhutan  Maldives     Nepal  \
# 2000              773.737   27869.200  396.036   451.041  3069.279
# 2001              638.058   32456.617  385.035   462.042  3267.297
# 2002              883.747   33707.064  418.038   594.054  2625.572
# 2003             1026.760   35672.576  377.701   506.046  2841.925
# 2004              949.753   37704.094  308.028   667.394  2669.576
# 2005             1327.454   39478.922  396.036   601.388  3083.947
# 2006             1650.150   43541.958  392.369   759.069  2563.233
# 2007             2273.540   44407.370  392.369   781.071  2614.571
# 2008             4217.050   49559.505  421.705   843.410  3421.311
# 2009             6776.616   53824.226  388.702   883.747  4334.394
# 2010             8470.770   59992.120  487.711   898.415  5056.793
# 2011            12251.447   63571.112  733.400   953.420  5533.503
# 2012            20454.526   67480.134  817.741  1078.098  5845.198
# ...

# %%
sdf2.sum().plot(kind='bar')

# %% [markdown]
# ## H/W use % of forest area and % of agriculture area and plot graph against.
