# %%
# import pandas
import pandas as pd

# %%
# read csv file, csv files contains description lines at the top so we skip
# those rows
df = pd.read_csv('nepal.csv', skiprows=3)

# %%
# show top 5 rows
df.head()
# Out:
#   Country Name Country Code  \
# 0        Nepal          NPL
# 1        Nepal          NPL
# 2        Nepal          NPL
# 3        Nepal          NPL
# 4        Nepal          NPL
#
#                                       Indicator Name     Indicator Code  1960  \
# 0                   Agricultural machinery, tractors     AG.AGR.TRAC.NO   NaN
# 1  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS   NaN
# 2  Fertilizer consumption (kilograms per hectare ...     AG.CON.FERT.ZS   NaN
# 3                         Agricultural land (sq. km)     AG.LND.AGRI.K2   NaN
# 4                 Agricultural land (% of land area)     AG.LND.AGRI.ZS   NaN
#
#            1961          1962          1963          1964          1965  \
# 0    180.000000    190.000000    200.000000    215.000000    225.000000
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3  35530.000000  35530.000000  35630.000000  35530.000000  35530.000000
# 4     24.846154     24.846154     24.916084     24.846154     24.846154
#
#       ...               2007          2008          2009          2010  \
# 0     ...                NaN           NaN           NaN           NaN
# 1     ...                NaN           NaN           NaN           NaN
# 2     ...           1.608929      1.364865     18.202727     25.086697
# 3     ...       41660.000000  41520.000000  41400.000000  41260.000000
# 4     ...          29.061737     28.964074     28.880363     28.782700
#
#            2011          2012          2013  2014  2015  Unnamed: 60
# 0           NaN           NaN           NaN   NaN   NaN          NaN
# 1           NaN           NaN           NaN   NaN   NaN          NaN
# 2     34.883710     44.069877     57.728477   NaN   NaN          NaN
# 3  41266.000000  41210.000000  41210.000000   NaN   NaN          NaN
# 4     28.786885     28.747820     28.747820   NaN   NaN          NaN
#
# [5 rows x 61 columns]

# %% [markdown]
# #### Task: Select by columns
# ---

# %%
# select using column names
df1 = df[['Indicator Name', '2010', '2011', '2012']]

# %%
df1.head()
# Out:
#                                       Indicator Name          2010  \
# 0                   Agricultural machinery, tractors           NaN
# 1  Fertilizer consumption (% of fertilizer produc...           NaN
# 2  Fertilizer consumption (kilograms per hectare ...     25.086697
# 3                         Agricultural land (sq. km)  41260.000000
# 4                 Agricultural land (% of land area)     28.782700
#
#            2011          2012
# 0           NaN           NaN
# 1           NaN           NaN
# 2     34.883710     44.069877
# 3  41266.000000  41210.000000
# 4     28.786885     28.747820

# %% [markdown]
# *Selecting columns by range / and column name separately and merging them together*

# %%
# slice all the rows
df.ix[:].head(3)
# Out:
#   Country Name Country Code  \
# 0        Nepal          NPL
# 1        Nepal          NPL
# 2        Nepal          NPL
#
#                                       Indicator Name     Indicator Code  1960  \
# 0                   Agricultural machinery, tractors     AG.AGR.TRAC.NO   NaN
# 1  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS   NaN
# 2  Fertilizer consumption (kilograms per hectare ...     AG.CON.FERT.ZS   NaN
#
#     1961   1962   1963   1964   1965     ...           2007      2008  \
# 0  180.0  190.0  200.0  215.0  225.0     ...            NaN       NaN
# 1    NaN    NaN    NaN    NaN    NaN     ...            NaN       NaN
# 2    NaN    NaN    NaN    NaN    NaN     ...       1.608929  1.364865
#
#         2009       2010      2011       2012       2013  2014  2015  \
# 0        NaN        NaN       NaN        NaN        NaN   NaN   NaN
# 1        NaN        NaN       NaN        NaN        NaN   NaN   NaN
# 2  18.202727  25.086697  34.88371  44.069877  57.728477   NaN   NaN
#
#    Unnamed: 60
# 0          NaN
# 1          NaN
# 2          NaN
#
# [3 rows x 61 columns]

# %%
# slice all rows with column range
df.ix[:,'2010':'2015'].head(3)
# Out:
#         2010      2011       2012       2013  2014  2015
# 0        NaN       NaN        NaN        NaN   NaN   NaN
# 1        NaN       NaN        NaN        NaN   NaN   NaN
# 2  25.086697  34.88371  44.069877  57.728477   NaN   NaN

# %%
# select using column name list
df[['Indicator Name']].head(3)
# Out:
#                                       Indicator Name
# 0                   Agricultural machinery, tractors
# 1  Fertilizer consumption (% of fertilizer produc...
# 2  Fertilizer consumption (kilograms per hectare ...

# %%
# now combine those two into single dataframe 
df2 = pd.concat([df[['Indicator Name']], df.ix[:,'2010':'2015']], axis=1).head(3)

# %%
df2.head(3)
# Out:
#                                       Indicator Name       2010      2011  \
# 0                   Agricultural machinery, tractors        NaN       NaN
# 1  Fertilizer consumption (% of fertilizer produc...        NaN       NaN
# 2  Fertilizer consumption (kilograms per hectare ...  25.086697  34.88371
#
#         2012       2013  2014  2015
# 0        NaN        NaN   NaN   NaN
# 1        NaN        NaN   NaN   NaN
# 2  44.069877  57.728477   NaN   NaN

# %%
# see how axis value changes the dataframe
pd.concat([df[['Indicator Name']], df.ix[:,'2010':'2015']], axis=0).head(3)
# Out:
#    2010  2011  2012  2013  2014  2015  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN
#
#                                       Indicator Name
# 0                   Agricultural machinery, tractors
# 1  Fertilizer consumption (% of fertilizer produc...
# 2  Fertilizer consumption (kilograms per hectare ...

# %% [markdown]
# **Task: Remove NaN**

# %%
# drop rows if NaN, default how is any i.e if any of the column has NaN
df1.dropna().head(3)
# Out:
#                                       Indicator Name          2010  \
# 2  Fertilizer consumption (kilograms per hectare ...     25.086697
# 3                         Agricultural land (sq. km)  41260.000000
# 4                 Agricultural land (% of land area)     28.782700
#
#            2011          2012
# 2     34.883710     44.069877
# 3  41266.000000  41210.000000
# 4     28.786885     28.747820

# %%
# only drop if all the column has NaN
df2.dropna(axis=1, how='all')
# Out:
#                                       Indicator Name       2010      2011  \
# 0                   Agricultural machinery, tractors        NaN       NaN
# 1  Fertilizer consumption (% of fertilizer produc...        NaN       NaN
# 2  Fertilizer consumption (kilograms per hectare ...  25.086697  34.88371
#
#         2012       2013
# 0        NaN        NaN
# 1        NaN        NaN
# 2  44.069877  57.728477

# %%
# df1.set_axis

# %%
df3 = df1.transpose()

# %%
df3.head()
# Out:
#                                             0     \
# Indicator Name  Agricultural machinery, tractors
# 2010                                         NaN
# 2011                                         NaN
# 2012                                         NaN
#
#                                                              1     \
# Indicator Name  Fertilizer consumption (% of fertilizer produc...
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
#                                                              2     \
# Indicator Name  Fertilizer consumption (kilograms per hectare ...
# 2010                                                      25.0867
# 2011                                                      34.8837
# 2012                                                      44.0699
#
#                                       3     \
# Indicator Name  Agricultural land (sq. km)
# 2010                                 41260
# 2011                                 41266
# 2012                                 41210
#
#                                               4                       5     \
# Indicator Name  Agricultural land (% of land area)  Arable land (hectares)
# 2010                                       28.7827                2.18e+06
# 2011                                       28.7869              2.1627e+06
# 2012                                       28.7478               2.118e+06
#
#                                              6     \
# Indicator Name  Arable land (hectares per person)
# 2010                                    0.0811135
# 2011                                    0.0795718
# 2012                                    0.0770167
#
#                                         7     \
# Indicator Name  Arable land (% of land area)
# 2010                                 15.2075
# 2011                                 15.0869
# 2012                                  14.775
#
#                                                    8     \
# Indicator Name  Land under cereal production (hectares)
# 2010                                        3.39355e+06
# 2011                                        3.46851e+06
# 2012                                        3.48453e+06
#
#                                                9     \
# Indicator Name  Permanent cropland (% of land area)
# 2010                                        1.06034
# 2011                                        1.17614
# 2012                                        1.45099
#
#                                       ...                          \
# Indicator Name                        ...
# 2010                                  ...
# 2011                                  ...
# 2012                                  ...
#
#                                                              1409  \
# Indicator Name  Account at a financial institution (% age 15+)...
# 2010                                                          NaN
# 2011                                                      25.3086
# 2012                                                          NaN
#
#                                                              1410  \
# Indicator Name  Account at a financial institution, male (% ag...
# 2010                                                          NaN
# 2011                                                      29.5583
# 2012                                                          NaN
#
#                                                              1411  \
# Indicator Name  Account at a financial institution, female (% ...
# 2010                                                          NaN
# 2011                                                      21.2196
# 2012                                                          NaN
#
#                                                              1412  \
# Indicator Name  Account at a financial institution, income, po...
# 2010                                                          NaN
# 2011                                                       14.379
# 2012                                                          NaN
#
#                                                              1413  \
# Indicator Name  Account at a financial institution, income, ri...
# 2010                                                          NaN
# 2011                                                      32.5893
# 2012                                                          NaN
#
#                                            1414  \
# Indicator Name  Mobile account (% age 15+) [w2]
# 2010                                        NaN
# 2011                                        NaN
# 2012                                        NaN
#
#                                                  1415  \
# Indicator Name  Mobile account, male (% age 15+) [w2]
# 2010                                              NaN
# 2011                                              NaN
# 2012                                              NaN
#
#                                                    1416  \
# Indicator Name  Mobile account, female (% age 15+) [w2]
# 2010                                                NaN
# 2011                                                NaN
# 2012                                                NaN
#
#                                                              1417  \
# Indicator Name  Mobile account, income, poorest 40% (% ages 15...
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
#                                                              1418
# Indicator Name  Mobile account, income, richest 60% (% ages 15...
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# [4 rows x 1419 columns]

# %%
df3.reindex_axis(df3.columns, axis=1)
# Out:
#                                             0     \
# Indicator Name  Agricultural machinery, tractors
# 2010                                         NaN
# 2011                                         NaN
# 2012                                         NaN
#
#                                                              1     \
# Indicator Name  Fertilizer consumption (% of fertilizer produc...
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
#                                                              2     \
# Indicator Name  Fertilizer consumption (kilograms per hectare ...
# 2010                                                      25.0867
# 2011                                                      34.8837
# 2012                                                      44.0699
#
#                                       3     \
# Indicator Name  Agricultural land (sq. km)
# 2010                                 41260
# 2011                                 41266
# 2012                                 41210
#
#                                               4                       5     \
# Indicator Name  Agricultural land (% of land area)  Arable land (hectares)
# 2010                                       28.7827                2.18e+06
# 2011                                       28.7869              2.1627e+06
# 2012                                       28.7478               2.118e+06
#
#                                              6     \
# Indicator Name  Arable land (hectares per person)
# 2010                                    0.0811135
# 2011                                    0.0795718
# 2012                                    0.0770167
#
#                                         7     \
# Indicator Name  Arable land (% of land area)
# 2010                                 15.2075
# 2011                                 15.0869
# 2012                                  14.775
#
#                                                    8     \
# Indicator Name  Land under cereal production (hectares)
# 2010                                        3.39355e+06
# 2011                                        3.46851e+06
# 2012                                        3.48453e+06
#
#                                                9     \
# Indicator Name  Permanent cropland (% of land area)
# 2010                                        1.06034
# 2011                                        1.17614
# 2012                                        1.45099
#
#                                       ...                          \
# Indicator Name                        ...
# 2010                                  ...
# 2011                                  ...
# 2012                                  ...
#
#                                                              1409  \
# Indicator Name  Account at a financial institution (% age 15+)...
# 2010                                                          NaN
# 2011                                                      25.3086
# 2012                                                          NaN
#
#                                                              1410  \
# Indicator Name  Account at a financial institution, male (% ag...
# 2010                                                          NaN
# 2011                                                      29.5583
# 2012                                                          NaN
#
#                                                              1411  \
# Indicator Name  Account at a financial institution, female (% ...
# 2010                                                          NaN
# 2011                                                      21.2196
# 2012                                                          NaN
#
#                                                              1412  \
# Indicator Name  Account at a financial institution, income, po...
# 2010                                                          NaN
# 2011                                                       14.379
# 2012                                                          NaN
#
#                                                              1413  \
# Indicator Name  Account at a financial institution, income, ri...
# 2010                                                          NaN
# 2011                                                      32.5893
# 2012                                                          NaN
#
#                                            1414  \
# Indicator Name  Mobile account (% age 15+) [w2]
# 2010                                        NaN
# 2011                                        NaN
# 2012                                        NaN
#
#                                                  1415  \
# Indicator Name  Mobile account, male (% age 15+) [w2]
# 2010                                              NaN
# 2011                                              NaN
# 2012                                              NaN
#
#                                                    1416  \
# Indicator Name  Mobile account, female (% age 15+) [w2]
# 2010                                                NaN
# 2011                                                NaN
# 2012                                                NaN
#
#                                                              1417  \
# Indicator Name  Mobile account, income, poorest 40% (% ages 15...
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
#                                                              1418
# Indicator Name  Mobile account, income, richest 60% (% ages 15...
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# [4 rows x 1419 columns]

# %%
df3.ix[0, :]
# Out:
# 0                        Agricultural machinery, tractors
# 1       Fertilizer consumption (% of fertilizer produc...
# 2       Fertilizer consumption (kilograms per hectare ...
# 3                              Agricultural land (sq. km)
# 4                      Agricultural land (% of land area)
# 5                                  Arable land (hectares)
# 6                       Arable land (hectares per person)
# 7                            Arable land (% of land area)
# 8                 Land under cereal production (hectares)
# 9                     Permanent cropland (% of land area)
# 10      Rural land area where elevation is below 5 met...
# 11      Rural land area where elevation is below 5 met...
# 12      Urban land area where elevation is below 5 met...
# 13      Urban land area where elevation is below 5 met...
# 14      Land area where elevation is below 5 meters (%...
# 15                                   Forest area (sq. km)
# 16                           Forest area (% of land area)
# 17      Agricultural irrigated land (% of total agricu...
# 18           Average precipitation in depth (mm per year)
# 19                                     Land area (sq. km)
# 20                               Rural land area (sq. km)
# 21                               Urban land area (sq. km)
# 22      Agricultural machinery, tractors per 100 sq. k...
# 23                        Cereal production (metric tons)
# 24                Crop production index (2004-2006 = 100)
# 25                Food production index (2004-2006 = 100)
# 26           Livestock production index (2004-2006 = 100)
# 27                                  Surface area (sq. km)
# 28                          Cereal yield (kg per hectare)
# 29                           Trade in services (% of GDP)
#                               ...
# 1389    Merchandise exports to low- and middle-income ...
# 1390    Merchandise exports to low- and middle-income ...
# 1391    Merchandise exports to low- and middle-income ...
# 1392    Merchandise exports to low- and middle-income ...
# 1393    Merchandise exports to low- and middle-income ...
# 1394    Merchandise exports by the reporting economy, ...
# 1395    Merchandise exports by the reporting economy (...
# 1396    Merchandise exports to low- and middle-income ...
# 1397                      Export value index (2000 = 100)
# 1398    Computer, communications and other services (%...
# 1399             Commercial service exports (current US$)
# 1400                High-technology exports (current US$)
# 1401    High-technology exports (% of manufactured exp...
# 1402    Transport services (% of commercial service ex...
# 1403    Travel services (% of commercial service exports)
# 1404             Battle-related deaths (number of people)
# 1405    Internally displaced persons (number, high est...
# 1406    Internally displaced persons (number, low esti...
# 1407           Intentional homicides (per 100,000 people)
# 1408    Presence of peace keepers (number of troops, p...
# 1409    Account at a financial institution (% age 15+)...
# 1410    Account at a financial institution, male (% ag...
# 1411    Account at a financial institution, female (% ...
# 1412    Account at a financial institution, income, po...
# 1413    Account at a financial institution, income, ri...
# 1414                      Mobile account (% age 15+) [w2]
# 1415                Mobile account, male (% age 15+) [w2]
# 1416              Mobile account, female (% age 15+) [w2]
# 1417    Mobile account, income, poorest 40% (% ages 15...
# 1418    Mobile account, income, richest 60% (% ages 15...
# Name: Indicator Name, dtype: object

# %%
# doesnot work
df3.reindex_axis(df3.ix[0, :], axis=1)
# Out:
# Indicator Name  Agricultural machinery, tractors  \
# Indicator Name                               NaN
# 2010                                         NaN
# 2011                                         NaN
# 2012                                         NaN
#
# Indicator Name  Fertilizer consumption (% of fertilizer production)  \
# Indicator Name                                                NaN
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# Indicator Name  Fertilizer consumption (kilograms per hectare of arable land)  \
# Indicator Name                                                NaN
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# Indicator Name  Agricultural land (sq. km)  \
# Indicator Name                         NaN
# 2010                                   NaN
# 2011                                   NaN
# 2012                                   NaN
#
# Indicator Name  Agricultural land (% of land area)  Arable land (hectares)  \
# Indicator Name                                 NaN                     NaN
# 2010                                           NaN                     NaN
# 2011                                           NaN                     NaN
# 2012                                           NaN                     NaN
#
# Indicator Name  Arable land (hectares per person)  \
# Indicator Name                                NaN
# 2010                                          NaN
# 2011                                          NaN
# 2012                                          NaN
#
# Indicator Name  Arable land (% of land area)  \
# Indicator Name                           NaN
# 2010                                     NaN
# 2011                                     NaN
# 2012                                     NaN
#
# Indicator Name  Land under cereal production (hectares)  \
# Indicator Name                                      NaN
# 2010                                                NaN
# 2011                                                NaN
# 2012                                                NaN
#
# Indicator Name  Permanent cropland (% of land area)  \
# Indicator Name                                  NaN
# 2010                                            NaN
# 2011                                            NaN
# 2012                                            NaN
#
# Indicator Name                          ...                            \
# Indicator Name                          ...
# 2010                                    ...
# 2011                                    ...
# 2012                                    ...
#
# Indicator Name  Account at a financial institution (% age 15+) [ts]  \
# Indicator Name                                                NaN
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# Indicator Name  Account at a financial institution, male (% age 15+) [ts]  \
# Indicator Name                                                NaN
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# Indicator Name  Account at a financial institution, female (% age 15+) [ts]  \
# Indicator Name                                                NaN
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# Indicator Name  Account at a financial institution, income, poorest 40% (% ages 15+) [ts]  \
# Indicator Name                                                NaN
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# Indicator Name  Account at a financial institution, income, richest 60% (% ages 15+) [ts]  \
# Indicator Name                                                NaN
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# Indicator Name  Mobile account (% age 15+) [w2]  \
# Indicator Name                              NaN
# 2010                                        NaN
# 2011                                        NaN
# 2012                                        NaN
#
# Indicator Name  Mobile account, male (% age 15+) [w2]  \
# Indicator Name                                    NaN
# 2010                                              NaN
# 2011                                              NaN
# 2012                                              NaN
#
# Indicator Name  Mobile account, female (% age 15+) [w2]  \
# Indicator Name                                      NaN
# 2010                                                NaN
# 2011                                                NaN
# 2012                                                NaN
#
# Indicator Name  Mobile account, income, poorest 40% (% ages 15+) [w2]  \
# Indicator Name                                                NaN
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# Indicator Name  Mobile account, income, richest 60% (% ages 15+) [w2]
# Indicator Name                                                NaN
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# [4 rows x 1419 columns]

# %%
df1.head()
# Out:
#                                       Indicator Name          2010  \
# 0                   Agricultural machinery, tractors           NaN
# 1  Fertilizer consumption (% of fertilizer produc...           NaN
# 2  Fertilizer consumption (kilograms per hectare ...     25.086697
# 3                         Agricultural land (sq. km)  41260.000000
# 4                 Agricultural land (% of land area)     28.782700
#
#            2011          2012
# 0           NaN           NaN
# 1           NaN           NaN
# 2     34.883710     44.069877
# 3  41266.000000  41210.000000
# 4     28.786885     28.747820

# %%
df5 = df1.set_index('Indicator Name').head(3)

# %%
df5.transpose()
# Out:
# Indicator Name  Agricultural machinery, tractors  \
# 2010                                         NaN
# 2011                                         NaN
# 2012                                         NaN
#
# Indicator Name  Fertilizer consumption (% of fertilizer production)  \
# 2010                                                          NaN
# 2011                                                          NaN
# 2012                                                          NaN
#
# Indicator Name  Fertilizer consumption (kilograms per hectare of arable land)
# 2010                                                    25.086697
# 2011                                                    34.883710
# 2012                                                    44.069877

# %%
# pd.pivot_table?
