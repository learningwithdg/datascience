# %% [markdown]
# # Numpy III
# ---

# %%
import numpy as np

# %% [markdown]
# ### Numpy functions

# %% [markdown]
# **Generating Samples**

# %% [markdown]
# *generate 50 random samples*

# %%
np.random.rand(50)
# Out:
# array([ 0.31725627,  0.16464475,  0.49365883,  0.63511249,  0.41984105,
#         0.82241632,  0.83122737,  0.39569491,  0.57584068,  0.51570949,
#         0.64637529,  0.8477091 ,  0.64188255,  0.88782705,  0.91239555,
#         0.28486641,  0.04916673,  0.73389728,  0.24132701,  0.20029013,
#         0.19078488,  0.650037  ,  0.82716579,  0.49560402,  0.46558514,
#         0.38948747,  0.85342612,  0.7053237 ,  0.46280375,  0.67848103,
#         0.12438979,  0.62296875,  0.7444401 ,  0.27385024,  0.62153084,
#         0.67179362,  0.22777084,  0.07616346,  0.54093809,  0.52017278,
#         0.38359243,  0.0477398 ,  0.8299088 ,  0.20010208,  0.27222176,
#         0.08865259,  0.3872127 ,  0.15830991,  0.11991698,  0.2336863 ])

# %% [markdown]
# *generate 50 linear spaced samples between 0 and 1*

# %%
np.linspace(0, 1)
# Out:
# array([ 0.        ,  0.02040816,  0.04081633,  0.06122449,  0.08163265,
#         0.10204082,  0.12244898,  0.14285714,  0.16326531,  0.18367347,
#         0.20408163,  0.2244898 ,  0.24489796,  0.26530612,  0.28571429,
#         0.30612245,  0.32653061,  0.34693878,  0.36734694,  0.3877551 ,
#         0.40816327,  0.42857143,  0.44897959,  0.46938776,  0.48979592,
#         0.51020408,  0.53061224,  0.55102041,  0.57142857,  0.59183673,
#         0.6122449 ,  0.63265306,  0.65306122,  0.67346939,  0.69387755,
#         0.71428571,  0.73469388,  0.75510204,  0.7755102 ,  0.79591837,
#         0.81632653,  0.83673469,  0.85714286,  0.87755102,  0.89795918,
#         0.91836735,  0.93877551,  0.95918367,  0.97959184,  1.        ])

# %%
# sample size of 20
np.linspace(0, 1, num=20)
# Out:
# array([ 0.        ,  0.05263158,  0.10526316,  0.15789474,  0.21052632,
#         0.26315789,  0.31578947,  0.36842105,  0.42105263,  0.47368421,
#         0.52631579,  0.57894737,  0.63157895,  0.68421053,  0.73684211,
#         0.78947368,  0.84210526,  0.89473684,  0.94736842,  1.        ])

# %% [markdown]
# **Constants**

# %% [markdown]
# $\pi$

# %%
np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ## Working with numpy functions ( or called as UFunc )

# %% [markdown]
# **Trig Functions**

# %%
np.sin(32)
# Out:
# 0.55142668124169059

# %% [markdown]
# *broadcast*

# %%
np.sin(np.array([15, 20, 25, 30, 35]))
# Out:
# array([ 0.65028784,  0.91294525, -0.13235175, -0.98803162, -0.42818267])

# %% [markdown]
# *Note: above function returned new array obtained by applying __sin__ to every element of input array*

# %% [markdown]
# # Matplotlib I
# ---

# %%
import matplotlib.pyplot as plt

# %%
# This is required to embeded plots/figures into jupyter notebook
# %matplotlib inline

# %% [markdown]
# *Plotting a array*

# %%
plt.plot(np.arange(0, 100))

# %% [markdown]
# *Here x-axis is defined by index of array and y-axis is value of array*

# %% [markdown]
# *Which can be more elaborated by figure below*

# %%
y = np.linspace(0, 1, num=100)

# %%
y
# Out:
# array([ 0.        ,  0.01010101,  0.02020202,  0.03030303,  0.04040404,
#         0.05050505,  0.06060606,  0.07070707,  0.08080808,  0.09090909,
#         0.1010101 ,  0.11111111,  0.12121212,  0.13131313,  0.14141414,
#         0.15151515,  0.16161616,  0.17171717,  0.18181818,  0.19191919,
#         0.2020202 ,  0.21212121,  0.22222222,  0.23232323,  0.24242424,
#         0.25252525,  0.26262626,  0.27272727,  0.28282828,  0.29292929,
#         0.3030303 ,  0.31313131,  0.32323232,  0.33333333,  0.34343434,
#         0.35353535,  0.36363636,  0.37373737,  0.38383838,  0.39393939,
#         0.4040404 ,  0.41414141,  0.42424242,  0.43434343,  0.44444444,
#         0.45454545,  0.46464646,  0.47474747,  0.48484848,  0.49494949,
#         0.50505051,  0.51515152,  0.52525253,  0.53535354,  0.54545455,
#         0.55555556,  0.56565657,  0.57575758,  0.58585859,  0.5959596 ,
#         0.60606061,  0.61616162,  0.62626263,  0.63636364,  0.64646465,
# ...

# %%
plt.plot(y)

# %% [markdown]
# **Let's plot sin**
#
# $$y = sin(x) \text{ where }x=\pi\to-\pi$$

# %%
x = np.linspace(-np.pi, np.pi, num=100)
x
# Out:
# array([-3.14159265, -3.07812614, -3.01465962, -2.9511931 , -2.88772658,
#        -2.82426006, -2.76079354, -2.69732703, -2.63386051, -2.57039399,
#        -2.50692747, -2.44346095, -2.37999443, -2.31652792, -2.2530614 ,
#        -2.18959488, -2.12612836, -2.06266184, -1.99919533, -1.93572881,
#        -1.87226229, -1.80879577, -1.74532925, -1.68186273, -1.61839622,
#        -1.5549297 , -1.49146318, -1.42799666, -1.36453014, -1.30106362,
#        -1.23759711, -1.17413059, -1.11066407, -1.04719755, -0.98373103,
#        -0.92026451, -0.856798  , -0.79333148, -0.72986496, -0.66639844,
#        -0.60293192, -0.53946541, -0.47599889, -0.41253237, -0.34906585,
#        -0.28559933, -0.22213281, -0.1586663 , -0.09519978, -0.03173326,
#         0.03173326,  0.09519978,  0.1586663 ,  0.22213281,  0.28559933,
#         0.34906585,  0.41253237,  0.47599889,  0.53946541,  0.60293192,
#         0.66639844,  0.72986496,  0.79333148,  0.856798  ,  0.92026451,
# ...

# %%
y = np.sin(x)
y
# Out:
# array([ -1.22464680e-16,  -6.34239197e-02,  -1.26592454e-01,
#         -1.89251244e-01,  -2.51147987e-01,  -3.12033446e-01,
#         -3.71662456e-01,  -4.29794912e-01,  -4.86196736e-01,
#         -5.40640817e-01,  -5.92907929e-01,  -6.42787610e-01,
#         -6.90079011e-01,  -7.34591709e-01,  -7.76146464e-01,
#         -8.14575952e-01,  -8.49725430e-01,  -8.81453363e-01,
#         -9.09631995e-01,  -9.34147860e-01,  -9.54902241e-01,
#         -9.71811568e-01,  -9.84807753e-01,  -9.93838464e-01,
#         -9.98867339e-01,  -9.99874128e-01,  -9.96854776e-01,
#         -9.89821442e-01,  -9.78802446e-01,  -9.63842159e-01,
#         -9.45000819e-01,  -9.22354294e-01,  -8.95993774e-01,
#         -8.66025404e-01,  -8.32569855e-01,  -7.95761841e-01,
#         -7.55749574e-01,  -7.12694171e-01,  -6.66769001e-01,
#         -6.18158986e-01,  -5.67059864e-01,  -5.13677392e-01,
#         -4.58226522e-01,  -4.00930535e-01,  -3.42020143e-01,
# ...

# %%
plt.plot(x, y)

# %% [markdown]
# **Let's plot sin and cos side by side**
#
# $$y = cos(x) \text{ where }x = \pi\to-\pi$$

# %%
plt.plot(x, np.cos(x))

# %% [markdown]
# *both in single plot*

# %%
plt.plot(x, np.sin(x), x, np.cos(x))

# %% [markdown]
# *Matplotlib automatically uses different color for different lines*

# %% [markdown]
# *Or use consecutive plot command and show final plot*

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# *Above plots are displayed using matplotlib defaults, such as line color, label font, line width and so on.*

# %%
# for example changing line color and line width
plt.plot(x, np.sin(x), color='red', linewidth=2.0)
plt.plot(x, np.cos(x), color='blue', linewidth=2.0)
plt.show()

# %% [markdown]
# **Changing limits**

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.plot(x, y_sin, color='red', linewidth=2.0)
plt.plot(x, y_cos, color='blue', linewidth=2.0)

# limiting plot values
plt.xlim(x.min()*1.1, x.max()*1.1)
plt.ylim(y_cos.min()*1.1, y_cos.max()*1.1)

plt.show()

# %% [markdown]
# *Above figure shows the whole signal, without clipping*

# %% [markdown]
# **Setting up ticks**

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.plot(x, y_sin, color='red', linewidth=2.0)
plt.plot(x, y_cos, color='blue', linewidth=2.0)

# limiting plot values
plt.xlim(x.min()*1.1, x.max()*1.1)
plt.ylim(y_cos.min()*1.1, y_cos.max()*1.1)

# ticks
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], 
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1])

plt.show()

# %% [markdown]
# *We can pass labels for the ticks, eg 2nd list on __plt.xticks__ is list of labels in __latex__*

# %% [markdown]
# **Adding legend**

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.plot(x, y_sin, color='red', linewidth=2.0, label='sine')
plt.plot(x, y_cos, color='blue', linewidth=2.0, label='cosine')

# limiting plot values
plt.xlim(x.min()*1.1, x.max()*1.1)
plt.ylim(y_cos.min()*1.1, y_cos.max()*1.1)

# ticks
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], 
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1])

# show labels with legend on specific location
plt.legend(loc="upper left", frameon=False)

plt.show()

# %% [markdown]
# ### Figure

# %% [markdown]
# Figure is a window, where we create plots and subplots.
#
# *Figure constitute plots (either single or multiple), legends, boundry, title etc.*

# %%
plt.figure(1)
plt.plot(np.linspace(0, 99))
plt.show()

# %% [markdown]
# ### Subplots
#
# Subplots are plots that are created inside figure

# %%
plt.figure(1)
plt.subplot(211) # or plt.subplot(2, 1, 1)
plt.plot(x, y_sin)
plt.subplot(212) # or plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.show()

# %% [markdown]
# *plt.subplot(number_of_rows, number_of_columns, number_of_the_plot)*
#
# Where above
#
# *first two arguments( or numbers in above case ) plt.subplot(21)* denotes that this figure has two rows and single column. while last argument ( or number in above case ) __1__ and __2__ in __211__ and __212__ respectively says first subplot must be drawn in 1st axes ( an area inside figure where graphs, label etc are drawn ) and second subplot must be drawn in 2nd axes.

# %% [markdown]
# **For example if we have grid of 4 subplots**

# %%
plt.figure(1)
# draw in first subplot ie. top-left one
plt.subplot(221) # or plt.subplot(2, 2, 1)
plt.plot(x, y_sin)

# draw in last subplot ie. bottom-right one
plt.subplot(224) # or plt.subplot(2, 2, 4)
plt.plot(x, y_cos)
plt.show()
